# %%
# !pip install sagemaker==1.72.0
# Out:
# Requirement already satisfied: sagemaker==1.72.0 in /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages (1.72.0)
# Requirement already satisfied: protobuf3-to-dict>=0.1.5 in /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages (from sagemaker==1.72.0) (0.1.5)
# Requirement already satisfied: importlib-metadata>=1.4.0 in /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages (from sagemaker==1.72.0) (3.1.0)
# Requirement already satisfied: numpy>=1.9.0 in /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages (from sagemaker==1.72.0) (1.19.4)
# Requirement already satisfied: protobuf>=3.1 in /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages (from sagemaker==1.72.0) (3.14.0)
# Requirement already satisfied: packaging>=20.0 in /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages (from sagemaker==1.72.0) (20.7)
# Requirement already satisfied: smdebug-rulesconfig==0.1.4 in /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages (from sagemaker==1.72.0) (0.1.4)
# Requirement already satisfied: boto3>=1.14.12 in /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages (from sagemaker==1.72.0) (1.16.37)
# Requirement already satisfied: scipy>=0.19.0 in /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages (from sagemaker==1.72.0) (1.4.1)
# Requirement already satisfied: botocore<1.20.0,>=1.19.37 in /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages (from boto3>=1.14.12->sagemaker==1.72.0) (1.19.37)
# Requirement already satisfied: s3transfer<0.4.0,>=0.3.0 in /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages (from boto3>=1.14.12->sagemaker==1.72.0) (0.3.3)
# Requirement already satisfied: jmespath<1.0.0,>=0.7.1 in /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages (from boto3>=1.14.12->sagemaker==1.72.0) (0.10.0)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages (from botocore<1.20.0,>=1.19.37->boto3>=1.14.12->sagemaker==1.72.0) (2.8.1)
# Requirement already satisfied: jmespath<1.0.0,>=0.7.1 in /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages (from boto3>=1.14.12->sagemaker==1.72.0) (0.10.0)
# Requirement already satisfied: urllib3<1.27,>=1.25.4 in /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages (from botocore<1.20.0,>=1.19.37->boto3>=1.14.12->sagemaker==1.72.0) (1.25.11)
# Requirement already satisfied: zipp>=0.5 in /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages (from importlib-metadata>=1.4.0->sagemaker==1.72.0) (3.4.0)
# Requirement already satisfied: pyparsing>=2.0.2 in /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages (from packaging>=20.0->sagemaker==1.72.0) (2.4.7)
# Requirement already satisfied: six>=1.9 in /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages (from protobuf>=3.1->sagemaker==1.72.0) (1.15.0)
# Requirement already satisfied: protobuf>=3.1 in /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages (from sagemaker==1.72.0) (3.14.0)
# Requirement already satisfied: six>=1.9 in /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages (from protobuf>=3.1->sagemaker==1.72.0) (1.15.0)
# Requirement already satisfied: six>=1.9 in /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages (from protobuf>=3.1->sagemaker==1.72.0) (1.15.0)
# Requirement already satisfied: botocore<1.20.0,>=1.19.37 in /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages (from boto3>=1.14.12->sagemaker==1.72.0) (1.19.37)
# Requirement already satisfied: numpy>=1.9.0 in /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages (from sagemaker==1.72.0) (1.19.4)
# WARNING: You are using pip version 20.3; however, version 21.0 is available.
# You should consider upgrading via the '/home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/bin/python -m pip install --upgrade pip' command.

# %%
# %matplotlib inline
import os
import ast
import json
import numpy as np
import pandas as pd
import source
import math

import matplotlib.pyplot as plt
from sklearn.datasets import load_boston
import sklearn.model_selection

import boto3
import sagemaker
from sagemaker import get_execution_role
from sagemaker.amazon.amazon_estimator import get_image_uri
from sagemaker.predictor import csv_serializer
from sagemaker.xgboost.estimator import XGBoost
from sagemaker.sklearn.estimator import SKLearn
from sklearn.preprocessing import MinMaxScaler, StandardScaler

from IPython.display import Audio
sound_file = './sound/beep.wav'

import warnings
warnings.filterwarnings('ignore')

session = sagemaker.Session()
role = get_execution_role()

# %%
pd.reset_option('display.max_rows')

# %% [markdown]
# <h2> Data Processing </h2>
#
# ROI is calculated using next price because we are trying to predict future ROI using the data from current time period.
# Referred to https://github.com/NGYB/Stocks/blob/master/StockPricePrediction/StockPricePrediction_v1c_xgboost.ipynb & https://towardsdatascience.com/cryptocurrency-price-prediction-using-lstms-tensorflow-for-hackers-part-iii-264fcdbccd3f

# %%
DATA_DIR = './data'

# %%
data = pd.read_csv(os.path.join(DATA_DIR, 'crypto-historical-data.csv'), 
                   parse_dates=['time'], 
                   index_col=0, 
                   keep_default_na=False,
                   header=0,
                   names=['market_cap', 'name', 'price', 'sym', 'time', 'volume'])

data.sort_values(by=['sym', 'time'], inplace=True)
data.reset_index(drop=True, inplace=True)

# %%
data['rank'] = data.groupby("time")["market_cap"] \
                    .rank("dense", ascending=False) \
                    .astype(int)

data['market_share'] = data.groupby('time')["market_cap"] \
                    .apply(lambda x: x/float(x.sum()))

data['age'] = data.groupby(['sym'])["time"] \
                    .apply(lambda x: x - min(x)) \
                    .dt.days + 1

previous_price = data.groupby(['sym'])['price'].shift(-1)
data['roi'] = data['price']/previous_price - 1

# %%
data[data['sym'] == 'ETH'].head(10)
# Out:
#          market_cap      name     price  sym       time     volume  rank  \
# 224231  167911000.0  Ethereum  0.753325  ETH 2015-08-08   674188.0     4
# 224232   42637600.0  Ethereum  0.701897  ETH 2015-08-09   532170.0     4
# 224233   43130000.0  Ethereum  0.708448  ETH 2015-08-10   405283.0     4
# 224234   42796500.0  Ethereum  1.070000  ETH 2015-08-11  1463100.0     4
# 224235   64018400.0  Ethereum  1.220000  ETH 2015-08-12  2150620.0     4
# 224236   73935400.0  Ethereum  1.830000  ETH 2015-08-13  4068680.0     4
# 224237  109594000.0  Ethereum  1.830000  ETH 2015-08-14  4637030.0     4
# 224238  109160000.0  Ethereum  1.690000  ETH 2015-08-15  2554360.0     4
# 224239  102028000.0  Ethereum  1.570000  ETH 2015-08-16  3550790.0     4
# 224240   95819700.0  Ethereum  1.200000  ETH 2015-08-17  1942830.0     4
#
#         market_share  age       roi
# 224231      0.034732    1  0.073270
# 224232      0.009641    2 -0.009247
# 224233      0.009581    3 -0.337899
# 224234      0.009541    4 -0.122951
# 224235      0.013904    5 -0.333333
# 224236      0.016312    6  0.000000
# 224237      0.024201    7  0.082840
# 224238      0.023926    8  0.076433
# 224239      0.022676    9  0.308333
# 224240      0.021582   10  0.100917

# %% [markdown]
# <h2> Data Selection </h2>

# %%
filtered = data.query('volume > 100000 & sym != ""')
filtered = filtered.query('sym == "ETH"')

# %%
filtered.sort_values(by=['sym', 'time'], inplace=True)
filtered.reset_index(drop=True, inplace=True)

# %% [markdown]
# <h2> Feature Engineering </h2>

# %%
feat = filtered.copy()

# %%
W = 3
TARGET = 'price'

# %%
properties = ['market_cap', 'price', 'volume', 'rank', 'market_share', 'age', 'roi']
feat_columns = []

for p in properties:
    for w in range(1, W+1):
        col_name = "{}_lag_{}".format(p, w)
        feat[col_name] = feat.groupby(['sym'])[p].shift(w)
        feat_columns.append(col_name)
    
    feat[p + '_mean'] = feat.groupby(['sym'])[p].shift(1) \
                                .transform(lambda x: x.rolling(w, min_periods=1).mean())
    feat[p + '_std'] = feat.groupby(['sym'])[p].shift(1) \
                                .transform(lambda x: x.rolling(w, min_periods=1).std())

feat.dropna(inplace=True)

# %%
feat.head()
# Out:
#     market_cap      name  price  sym       time     volume  rank  \
# 3   42796500.0  Ethereum   1.07  ETH 2015-08-11  1463100.0     4
# 4   64018400.0  Ethereum   1.22  ETH 2015-08-12  2150620.0     4
# 5   73935400.0  Ethereum   1.83  ETH 2015-08-13  4068680.0     4
# 6  109594000.0  Ethereum   1.83  ETH 2015-08-14  4637030.0     4
# 7  109160000.0  Ethereum   1.69  ETH 2015-08-15  2554360.0     4
#
#    market_share  age       roi  ...  age_lag_1  age_lag_2  age_lag_3  \
# 3      0.009541    4  0.140187  ...        3.0        2.0        1.0
# 4      0.013904    5  0.500000  ...        4.0        3.0        2.0
# 5      0.016312    6  0.000000  ...        5.0        4.0        3.0
# 6      0.024201    7 -0.076503  ...        6.0        5.0        4.0
# 7      0.023926    8 -0.071006  ...        7.0        6.0        5.0
#
#    age_mean  age_std  roi_lag_1  roi_lag_2  roi_lag_3  roi_mean   roi_std
# 3       2.0      1.0   0.510344   0.009333  -0.068268  0.150470  0.314066
# 4       3.0      1.0   0.140187   0.510344   0.009333  0.219955  0.259856
# 5       4.0      1.0   0.500000   0.140187   0.510344  0.383510  0.210788
# 6       5.0      1.0   0.000000   0.500000   0.140187  0.213396  0.257914
# 7       6.0      1.0  -0.076503   0.000000   0.500000  0.141166  0.313105
#
# [5 rows x 45 columns]

# %% [markdown]
# <h2> Data Split </h2>

# %%
VAL_START = pd.Timestamp('2017-04-25')
TEST_START = pd.Timestamp('2017-10-25')

# %%
train = feat.query("time < @VAL_START")
val = feat.query("time >= @VAL_START & time < @TEST_START")
trainval = feat.query("time <= @TEST_START")
test = feat.query("time >= @TEST_START")

# %%
cols_to_scale = feat_columns + [TARGET]

# %%
scaler_train = StandardScaler()
train_cols_scaled = scaler_train.fit_transform(train[cols_to_scale])
train_scaled = train.copy()
train_scaled[cols_to_scale] = train_cols_scaled

# %%
print(cols_to_scale)
print(scaler_train.var_)
print(scaler_train.mean_)
# Out:
# ['market_cap_lag_1', 'market_cap_lag_2', 'market_cap_lag_3', 'price_lag_1', 'price_lag_2', 'price_lag_3', 'volume_lag_1', 'volume_lag_2', 'volume_lag_3', 'rank_lag_1', 'rank_lag_2', 'rank_lag_3', 'market_share_lag_1', 'market_share_lag_2', 'market_share_lag_3', 'age_lag_1', 'age_lag_2', 'age_lag_3', 'roi_lag_1', 'roi_lag_2', 'roi_lag_3', 'price']
# [9.44029540e+17 9.25097659e+17 9.06196744e+17 1.17463805e+02
#  1.15293085e+02 1.13101657e+02 1.90377237e+15 1.90423395e+15
#  1.90462687e+15 7.82296608e-01 7.85099799e-01 7.87882379e-01
#  1.71415743e-03 1.70741731e-03 1.69725494e-03 3.23440000e+04
#  3.23440000e+04 3.23440000e+04 5.95480512e-03 5.95402053e-03
#  5.96355956e-03 1.19814276e+02]
# [8.87641789e+08 8.80615461e+08 8.73852413e+08 1.04847740e+01
#  1.04080676e+01 1.03313474e+01 2.24390934e+07 2.23817871e+07
#  2.23229053e+07 2.56179775e+00 2.56500803e+00 2.56821830e+00
#  6.39788099e-02 6.37561402e-02 6.35737997e-02 3.14000000e+02
#  3.13000000e+02 3.12000000e+02 9.66598180e-03 9.62998525e-03
#  9.52238947e-03 1.05639418e+01]

# %%
scaler_trainval = StandardScaler()
trainval_cols_scaled = scaler_trainval.fit_transform(trainval[cols_to_scale])
trainval_scaled = trainval.copy()
trainval_scaled[cols_to_scale] = trainval_cols_scaled

# %%
def scale_col(df, base, col):
    mean = df[base + '_mean']
    std = df[base + '_std']
    std = np.where(std == 0, 0.001, std)
    return (df[col] - mean)/std

# %%
val_scaled = val.copy()
for p in properties:
    val_scaled[p] = scale_col(val_scaled, p, p)
    for w in range(1, W+1):
        col_name = "{}_lag_{}".format(p, w)
        val_scaled[col_name] = scale_col(val_scaled, p, col_name)

# %%
test_scaled = test.copy()
for p in properties:
    test_scaled[p] = scale_col(test_scaled, p, p)
    
    for w in range(1, W+1):
        col_name = "{}_lag_{}".format(p, w)
        test_scaled[col_name] = scale_col(test_scaled, p, col_name)

# %%
test_scaled.describe()
# Out:
#        market_cap       price      volume          rank  market_share    age  \
# count  169.000000  169.000000  169.000000  1.690000e+02    169.000000  169.0
# mean    -0.008263    0.138561    1.001767 -2.511383e+05      0.132466    2.0
# std      4.270688    4.687974    6.175089  3.264875e+06      3.185049    0.0
# min    -39.450642  -36.711017   -4.481230 -4.244337e+07     -6.144347    2.0
# 25%     -0.972459   -1.025454   -1.167391  0.000000e+00     -1.592107    2.0
# 50%      0.325622    0.220591   -0.301052  0.000000e+00     -0.405553    2.0
# 75%      1.365829    1.372667    1.157391  0.000000e+00      1.305166    2.0
# max     10.454987   26.733397   52.275250  1.000000e+03     23.728305    2.0
#
#               roi  market_cap_lag_1  market_cap_lag_2  market_cap_lag_3  ...  \
# count  169.000000        169.000000        169.000000        169.000000  ...
# mean     0.134679          0.049450         -0.014020         -0.035430  ...
# std      2.866981          0.850413          0.726003          0.870460  ...
# min     -7.262917         -1.154553         -1.154611         -1.154272  ...
# 25%     -0.894646         -0.904223         -0.652847         -0.931094  ...
# 50%     -0.054148          0.116236         -0.032222         -0.078923  ...
# 75%      0.910702          0.927361          0.641495          0.884976  ...
# max     26.169837          1.154245          1.154700          1.154471  ...
#
#        age_lag_1  age_lag_2  age_lag_3    age_mean  age_std   roi_lag_1  \
# count      169.0      169.0      169.0  169.000000    169.0  169.000000
# mean         1.0        0.0       -1.0  892.000000      1.0    0.015302
# std          0.0        0.0        0.0   48.930222      0.0    0.830063
# min          1.0        0.0       -1.0  808.000000      1.0   -1.154689
# 25%          1.0        0.0       -1.0  850.000000      1.0   -0.758776
# 50%          1.0        0.0       -1.0  892.000000      1.0   -0.123688
# 75%          1.0        0.0       -1.0  934.000000      1.0    0.836068
# max          1.0        0.0       -1.0  976.000000      1.0    1.154169
#
#         roi_lag_2   roi_lag_3    roi_mean     roi_std
# count  169.000000  169.000000  169.000000  169.000000
# mean    -0.004192   -0.011110    0.004051    0.052680
# std      0.812500    0.813859    0.038886    0.032275
# min     -1.154700   -1.154699   -0.092198    0.003861
# 25%     -0.778780   -0.775199   -0.015667    0.027894
# 50%     -0.020239   -0.039284    0.003183    0.045900
# 75%      0.834001    0.760878    0.024373    0.065176
# max      1.154699    1.154663    0.169865    0.170359
#
# [8 rows x 42 columns]

# %%
test_scaled.head()
# Out:
#      market_cap      name      price  sym       time     volume  rank  \
# 809    0.644398  Ethereum   0.735762  ETH 2017-10-25  -0.966470   0.0
# 810    0.788165  Ethereum   0.329314  ETH 2017-10-26  -1.260235   0.0
# 811    0.325622  Ethereum  -0.186917  ETH 2017-10-27  -0.753086   0.0
# 812    0.405008  Ethereum  -1.401938  ETH 2017-10-28  -0.548184   0.0
# 813   -1.153368  Ethereum  14.099187  ETH 2017-10-29  43.840972   0.0
#
#      market_share  age       roi  ...  age_lag_1  age_lag_2  age_lag_3  \
# 809      5.409184  2.0 -0.228871  ...        1.0        0.0       -1.0
# 810      0.380912  2.0 -0.332212  ...        1.0        0.0       -1.0
# 811     -0.452637  2.0 -0.713053  ...        1.0        0.0       -1.0
# 812     -0.295124  2.0  7.492588  ...        1.0        0.0       -1.0
# 813      0.101809  2.0 -0.051774  ...        1.0        0.0       -1.0
#
#      age_mean  age_std  roi_lag_1  roi_lag_2  roi_lag_3  roi_mean   roi_std
# 809     808.0      1.0  -0.131352   1.059185  -0.927833  0.003183  0.034438
# 810     809.0      1.0  -0.644003  -0.508026   1.152029  0.011206  0.024698
# 811     810.0      1.0   1.039765  -0.954816  -0.084949 -0.001013  0.003861
# 812     811.0      1.0  -0.462727   1.147558  -0.684831 -0.001821  0.004202
# 813     812.0      1.0   1.133346  -0.758103  -0.375243  0.009634  0.017675
#
# [5 rows x 45 columns]

# %%
train_X = train_scaled[feat_columns]
train_Y = train_scaled[[TARGET]]

trainval_X = trainval_scaled[feat_columns]
trainval_Y = trainval_scaled[[TARGET]]

val_X = val_scaled[feat_columns]
val_Y = val_scaled[[TARGET]]

test_X = test_scaled[feat_columns]
test_Y = test_scaled[[TARGET]]

# %% [markdown]
# <h2> Training </h2>

# %%
prefix = 'xgboost-new'

pd.concat([train_Y, train_X], axis=1).to_csv(os.path.join(DATA_DIR, 'train.csv'), header=False, index=False)
pd.concat([val_Y, val_X], axis=1).to_csv(os.path.join(DATA_DIR, 'val.csv'), header=False, index=False)

train_location = session.upload_data(os.path.join(DATA_DIR, 'train.csv'), key_prefix=prefix)
val_location = session.upload_data(os.path.join(DATA_DIR, 'val.csv'), key_prefix=prefix)

train_input = sagemaker.s3_input(s3_data=train_location, content_type='text/csv')
val_input = sagemaker.s3_input(s3_data=val_location, content_type='text/csv')
# Out:
# 's3_input' class will be renamed to 'TrainingInput' in SageMaker Python SDK v2.
# 's3_input' class will be renamed to 'TrainingInput' in SageMaker Python SDK v2.

# %%
container = get_image_uri(session.boto_region_name, 'xgboost')

xgb = sagemaker.estimator.Estimator(container,
                                    role, 
                                    train_instance_count=1,
                                    train_instance_type='ml.m4.xlarge',
                                    output_path='s3://{}/{}/output'.format(session.default_bucket(), prefix),
                                    sagemaker_session=session)

xgb.set_hyperparameters(max_depth=3,
                        eta=0.1,
                        gamma=0.1,
                        min_child_weight=15,
                        subsample=0.8,
                        objective='reg:linear',
                        early_stopping_rounds=10,
                        num_round=200)

xgb.fit({'train': train_input, 'validation': val_input})
# Out:
# 'get_image_uri' method will be deprecated in favor of 'ImageURIProvider' class in SageMaker Python SDK v2.
# There is a more up to date SageMaker XGBoost image. To use the newer image, please set 'repo_version'='1.0-1'. For example:
# 	get_image_uri(region, 'xgboost', '1.0-1').
# Parameter image_name will be renamed to image_uri in SageMaker Python SDK v2.
# 2021-01-31 03:57:15 Starting - Starting the training job...
# 2021-01-31 03:57:17 Starting - Launching requested ML instances......
# 2021-01-31 03:58:21 Starting - Preparing the instances for training......
# 2021-01-31 03:59:37 Downloading - Downloading input data
# 2021-01-31 03:59:37 Training - Downloading the training image...
# 2021-01-31 04:00:10 Uploading - Uploading generated training model
# 2021-01-31 04:00:10 Completed - Training job completed
# Arguments: train
# [2021-01-31:03:59:58:INFO] Running standalone xgboost training.
# [2021-01-31:03:59:58:INFO] File size need to be processed in the node: 0.32mb. Available memory size in the node: 8430.83mb
# [2021-01-31:03:59:58:INFO] Determined delimiter of CSV input is ','
# [03:59:58] S3DistributionType set as FullyReplicated
# [03:59:58] 623x21 matrix with 13083 entries loaded from /opt/ml/input/data/train?format=csv&label_column=0&delimiter=,
# [2021-01-31:03:59:58:INFO] Determined delimiter of CSV input is ','
# [03:59:58] S3DistributionType set as FullyReplicated
# [03:59:58] 183x21 matrix with 3843 entries loaded from /opt/ml/input/data/validation?format=csv&label_column=0&delimiter=,
# [03:59:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=3
# [0]#011train-rmse:1.01118#011validation-rmse:4.18658
# Multiple eval metrics have been passed: 'validation-rmse' will be used for early stopping.
#
# Will train until validation-rmse hasn't improved in 10 rounds.
# [03:59:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=3
# [1]#011train-rmse:0.916133#011validation-rmse:4.18677
# [03:59:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=3
# [2]#011train-rmse:0.82892#011validation-rmse:4.18617
# [03:59:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=3
# [3]#011train-rmse:0.751038#011validation-rmse:4.17189
# [03:59:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 0 pruned nodes, max_depth=3
# [4]#011train-rmse:0.680835#011validation-rmse:4.15388
# [03:59:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=3
# [5]#011train-rmse:0.617305#011validation-rmse:4.14602
# [03:59:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=3
# [6]#011train-rmse:0.558984#011validation-rmse:4.13503
# [03:59:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 0 pruned nodes, max_depth=3
# [7]#011train-rmse:0.507872#011validation-rmse:4.12369
# [03:59:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=3
# [8]#011train-rmse:0.459201#011validation-rmse:4.11674
# [03:59:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 2 pruned nodes, max_depth=3
# [9]#011train-rmse:0.416914#011validation-rmse:4.10896
# [03:59:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 0 pruned nodes, max_depth=3
# [10]#011train-rmse:0.378392#011validation-rmse:4.10397
# [03:59:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 2 pruned nodes, max_depth=3
# [11]#011train-rmse:0.344092#011validation-rmse:4.1025
# [03:59:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=3
# [12]#011train-rmse:0.312032#011validation-rmse:4.09681
# [03:59:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 0 pruned nodes, max_depth=3
# [13]#011train-rmse:0.284477#011validation-rmse:4.09359
# [03:59:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 0 pruned nodes, max_depth=3
# [14]#011train-rmse:0.259782#011validation-rmse:4.09036
# [03:59:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 0 pruned nodes, max_depth=3
# [15]#011train-rmse:0.237652#011validation-rmse:4.09007
# [03:59:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 2 pruned nodes, max_depth=3
# [16]#011train-rmse:0.217562#011validation-rmse:4.08639
# [03:59:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=3
# [17]#011train-rmse:0.198954#011validation-rmse:4.08432
# [03:59:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 0 pruned nodes, max_depth=3
# [18]#011train-rmse:0.182985#011validation-rmse:4.0811
# [03:59:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 0 pruned nodes, max_depth=3
# [19]#011train-rmse:0.168904#011validation-rmse:4.08104
# [03:59:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 2 pruned nodes, max_depth=3
# [20]#011train-rmse:0.15657#011validation-rmse:4.07937
# [03:59:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=3
# [21]#011train-rmse:0.145007#011validation-rmse:4.07758
# [03:59:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 2 pruned nodes, max_depth=3
# [22]#011train-rmse:0.13465#011validation-rmse:4.07648
# [03:59:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 2 pruned nodes, max_depth=3
# [23]#011train-rmse:0.125576#011validation-rmse:4.07411
# [03:59:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 2 pruned nodes, max_depth=3
# [24]#011train-rmse:0.117866#011validation-rmse:4.07381
# [03:59:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 2 pruned nodes, max_depth=3
# [25]#011train-rmse:0.110017#011validation-rmse:4.07129
# [03:59:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=3
# [26]#011train-rmse:0.103548#011validation-rmse:4.06977
# [03:59:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=3
# [27]#011train-rmse:0.098022#011validation-rmse:4.06833
# [03:59:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=3
# [28]#011train-rmse:0.093203#011validation-rmse:4.06667
# [03:59:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 2 pruned nodes, max_depth=3
# [29]#011train-rmse:0.08864#011validation-rmse:4.0665
# [03:59:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 2 pruned nodes, max_depth=3
# [30]#011train-rmse:0.08483#011validation-rmse:4.06527
# [03:59:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 2 pruned nodes, max_depth=3
# [31]#011train-rmse:0.081476#011validation-rmse:4.06208
# [03:59:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 4 pruned nodes, max_depth=2
# [32]#011train-rmse:0.078555#011validation-rmse:4.06166
# [03:59:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 2 pruned nodes, max_depth=3
# [33]#011train-rmse:0.075398#011validation-rmse:4.0599
# [03:59:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 2 pruned nodes, max_depth=3
# [34]#011train-rmse:0.073111#011validation-rmse:4.0582
# [03:59:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2 extra nodes, 10 pruned nodes, max_depth=1
# [35]#011train-rmse:0.07198#011validation-rmse:4.05724
# [03:59:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [36]#011train-rmse:0.070108#011validation-rmse:4.05639
# [03:59:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 2 pruned nodes, max_depth=3
# [37]#011train-rmse:0.068506#011validation-rmse:4.05546
# [03:59:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 8 pruned nodes, max_depth=2
# [38]#011train-rmse:0.067535#011validation-rmse:4.05502
# [03:59:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 2 pruned nodes, max_depth=3
# [39]#011train-rmse:0.065816#011validation-rmse:4.05497
# [03:59:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 2 pruned nodes, max_depth=2
# [40]#011train-rmse:0.064861#011validation-rmse:4.05504
# [03:59:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 6 pruned nodes, max_depth=2
# [41]#011train-rmse:0.063783#011validation-rmse:4.05539
# [03:59:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 2 pruned nodes, max_depth=3
# [42]#011train-rmse:0.062534#011validation-rmse:4.0547
# [03:59:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 6 pruned nodes, max_depth=2
# [43]#011train-rmse:0.061501#011validation-rmse:4.05415
# [03:59:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2 extra nodes, 6 pruned nodes, max_depth=1
# [44]#011train-rmse:0.06106#011validation-rmse:4.05421
# [03:59:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 4 pruned nodes, max_depth=2
# [45]#011train-rmse:0.060483#011validation-rmse:4.05361
# [03:59:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 4 pruned nodes, max_depth=2
# [46]#011train-rmse:0.059372#011validation-rmse:4.05264
# [03:59:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 2 pruned nodes, max_depth=2
# [47]#011train-rmse:0.058295#011validation-rmse:4.05268
# [03:59:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 2 pruned nodes, max_depth=3
# [48]#011train-rmse:0.056937#011validation-rmse:4.05186
# [03:59:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 8 pruned nodes, max_depth=3
# [49]#011train-rmse:0.056023#011validation-rmse:4.05109
# [03:59:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 4 pruned nodes, max_depth=2
# [50]#011train-rmse:0.055353#011validation-rmse:4.05058
# [03:59:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 2 pruned nodes, max_depth=2
# [51]#011train-rmse:0.054751#011validation-rmse:4.05061
# [03:59:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 6 pruned nodes, max_depth=2
# [52]#011train-rmse:0.054165#011validation-rmse:4.04995
# [03:59:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 8 pruned nodes, max_depth=0
# [53]#011train-rmse:0.05416#011validation-rmse:4.04997
# [03:59:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 8 pruned nodes, max_depth=0
# [54]#011train-rmse:0.054151#011validation-rmse:4.04999
# [03:59:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 12 pruned nodes, max_depth=0
# [55]#011train-rmse:0.054148#011validation-rmse:4.05
# [03:59:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 10 pruned nodes, max_depth=0
# [56]#011train-rmse:0.054145#011validation-rmse:4.05002
# [03:59:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 4 pruned nodes, max_depth=2
# [57]#011train-rmse:0.053601#011validation-rmse:4.05003
# [03:59:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 12 pruned nodes, max_depth=0
# [58]#011train-rmse:0.053602#011validation-rmse:4.05003
# [03:59:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 8 pruned nodes, max_depth=0
# [59]#011train-rmse:0.053597#011validation-rmse:4.05005
# [03:59:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 12 pruned nodes, max_depth=0
# [60]#011train-rmse:0.053597#011validation-rmse:4.05005
# [03:59:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 2 pruned nodes, max_depth=2
# [61]#011train-rmse:0.052985#011validation-rmse:4.05007
# [03:59:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 10 pruned nodes, max_depth=0
# [62]#011train-rmse:0.052985#011validation-rmse:4.05007
# Stopping. Best iteration:
# [52]#011train-rmse:0.054165#011validation-rmse:4.04995
#
# Training seconds: 54
# Billable seconds: 54

# %%
predictor = xgb.deploy(initial_instance_count=1, instance_type='ml.m4.xlarge')
predictor.content_type = 'text/csv'
predictor.serializer = csv_serializer
# Out:
# Parameter image will be renamed to image_uri in SageMaker Python SDK v2.
# ---------------!

# %% [markdown]
# <h2> Predicting on Test Set </h2>

# %%
pred_Y = [predictor.predict(batch).decode('utf-8') for batch in np.array_split(test_X.values, 10)]
pred_Y = [ast.literal_eval(batch) for batch in pred_Y]
pred_Y = np.array([val for sublist in pred_Y for val in sublist])

# %%
pred_mean = test_scaled[TARGET+'_mean']
pred_std = test_scaled[TARGET+'_std']
pred = (pred_Y * pred_std) + pred_mean

# %%
test_result = test.copy()
test_result['pred'] = pred
test_result = test_result.set_index('time')

# %%
def get_mape(y_true, y_pred): 
    """
    Compute mean absolute percentage error (MAPE)
    """
    y_true, y_pred = np.array(y_true), np.array(y_pred)
    return np.mean(np.abs((y_true - y_pred) / y_true)) * 100

# %%
get_mape(test_result[TARGET], test_result['pred'])
# Out:
# 4.807952541063193

# %%
plt.figure(figsize=(10,5))

test_result[test_result['sym'] == 'ETH']['pred'].plot(label='Prediction', lw=1)
test_result[test_result['sym'] == 'ETH'][TARGET].plot(label='Actual', lw=1)

plt.legend()
plt.show()

# %% [markdown]
# <h2> Predicting on Train Set </h2>

# %%
pred_Y = [predictor.predict(batch).decode('utf-8') for batch in np.array_split(train_X.values, 200)]
pred_Y = [ast.literal_eval(batch) for batch in pred_Y]
pred_Y = np.array([val for sublist in pred_Y for val in sublist])

# %%
pred_mean = train[TARGET+'_mean']
pred_std = train[TARGET+'_std']
pred = pred_Y * math.sqrt(scaler_train.var_[-1]) + scaler_train.mean_[-1]
# pred = pred_Y * pred_std + pred_mean

# %%
train_result = train.copy()
train_result['pred'] = pred
train_result = train_result.set_index('time')

# %%
plt.figure(figsize=(10,5))

train_result[train_result['sym'] == 'ETH']['pred'].plot(label='Prediction', lw=1)
train_result[train_result['sym'] == 'ETH']['price'].plot(label='Actual', lw=1)

plt.legend()
plt.show()

# %%
predictor.delete_endpoint()

# %% [markdown]
# <h2> Trading </h2>

# %%
def update_mean(mean, t, new_value):
    if t == 0:
        return new_value
    else:
        return (mean * (t - 1) + new_value) / t

# Function to update standard deviation based on new value
def update_std(std, mean, new_mean, t, new_value):
    if t == 0:
        return 0
    else:
        return np.sqrt((std ** 2 * (t - 1) + (new_value - new_mean) * (new_value - mean)) / t)

# %%
# Function to execute the trading strategy over the trading horizon using asset matrix
def evaluate_strategy(result, n=10, initial_value=10000):
    total_value = initial_value
    mean_roi = 0
    std_roi = 0
    
    value_history = []
    roi_history = []
    
    t = 1

    dates = list(set(result.index))
    dates.sort()
    
    df = result.copy()
    df['predicted_roi'] = (df['pred']/df['price_lag_1']) - 1
    df.sort_values(by='predicted_roi', ascending=False, inplace=True)

    for date in dates:
        temp_df = df.query('time == @date & predicted_roi > 0')

        if not temp_df.empty:
            top_n = temp_df.nlargest(n, 'predicted_roi')
            selected_n = len(top_n)
            day_return = sum(top_n['roi'] * total_value / selected_n)
            day_roi = day_return/total_value
        else:
            day_return = 0
            day_roi = 0
        
        total_value += day_return
        percent_returns = (total_value/initial_value - 1) * 100

        prev_mean_roi = mean_roi
        mean_roi = update_mean(prev_mean_roi, t, day_roi)
        std_roi = update_std(std_roi, prev_mean_roi, mean_roi, t, day_roi)
        sharpe_ratio = mean_roi/std_roi
        
        value_history.append(total_value)
        roi_history.append(day_roi)

        t += 1
        
    print('Cumulative Returns: {:.2e}%'.format(percent_returns))
    
    history = pd.concat([pd.DataFrame(dates), pd.DataFrame(value_history), pd.DataFrame(roi_history)], axis=1)
    history.columns = ['time', 'total_value', 'roi']
    history = history.set_index('time')
    return sharpe_ratio, percent_returns, history

# %%
evaluate_strategy(test_result)
# Out:
# Cumulative Returns: 2.95e+01%
# (0.05550715591241655,
#  29.506065945135298,
#               total_value       roi
#  time
#  2017-10-25  10000.000000  0.000000
#  2017-10-26  10000.000000  0.000000
#  2017-10-27   9962.342815 -0.003766
#  2017-10-28   9962.342815  0.000000
#  2017-10-29  10049.201879  0.008719
#  ...                  ...       ...
#  2018-04-07  12460.303980  0.039449
#  2018-04-08  12460.303980  0.000000
#  2018-04-09  12460.303980  0.000000
#  2018-04-10  12950.606595  0.039349
#  2018-04-11  12950.606595  0.000000
#
#  [169 rows x 2 columns])
