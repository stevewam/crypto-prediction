# %%
# %%capture
# !pip install sagemaker==1.72.0

# %%
# %config InlineBackend.figure_format = 'svg'
# import importlib
# importlib.reload(source)

import warnings
warnings.filterwarnings("ignore")
import source

# %%
data_dict = source.load.load_data()
data = data_dict['data']
symbols = data_dict['symbols']

# %%
# collection = {}

# %% [markdown]
# <h2> SMA Evaluation </h2>

# %% [markdown]
# <h5> --- SMA Iteration 1 [SMA-1]</h5>

# %%
W = 3
target = 'price'
name = 'SMA-1'
sets = source.create.load_sets(data, target, W)

test_result = sets['test']['ori']
test_result['pred'] = test_result['price_mean']
test_result.set_index('time', drop=True, inplace=True)

trade_result = source.metric.trade(test_result, target)

print('RMSE: ', source.metric.RMSE(test_result, target))
source.plot.plot_history({name: trade_result}, 'Trading Result - ' + name)
# Out:
# Cumulative Returns: 2.46e+02%, Sharpe Ratio : 8.0784e-02
# RMSE:  114.7981112036905

# %% [markdown]
# <h5> --- SMA Iteration 2 [SMA-2]</h5>

# %%
W = 5
target = 'price'
name = 'SMA2-2'
sets = source.create.load_sets(data, target, W)

test_result = sets['test']['ori']
test_result['pred'] = test_result['price_mean']
test_result.set_index('time', drop=True, inplace=True)

trade_result = source.metric.trade(test_result, target)

print('RMSE: ', source.metric.RMSE(test_result, target))
source.plot.plot_history({name: trade_result}, 'Trading Result - ' + name)
# Out:
# Cumulative Returns: 1.01e+03%, Sharpe Ratio : 1.0250e-01
# RMSE:  135.40906275358125

# %% [markdown]
# <h5> --- SMA Iteration 3 [SMA-3] - Best Model - Benchmark</h5>

# %%
W = 7
target = 'price'
name = 'SMA-3'
sets = source.create.load_sets(data, target, W)

test_result = sets['test']['ori']
test_result['pred'] = test_result['price_mean']
test_result.set_index('time', drop=True, inplace=True)

trade_result = source.metric.trade(test_result, target)

print('RMSE: ', source.metric.RMSE(test_result, target))
source.plot.plot_history({name: trade_result}, 'Trading Result - ' + name)
# Cumulative Returns: 2.63e+03%, Sharpe Ratio : 1.1993e-01
# RMSE:  154.06047948087092
# Out:
# Cumulative Returns: 2.63e+03%, Sharpe Ratio : 1.1993e-01
# RMSE:  154.06047948087092

# %% [markdown]
# <h2> XGBoost Evaluation </h2>

# %% [markdown]
# <h5> --- XGBoost Iteration 1 [XGB-1]</h5>

# %%
W = 5
target = 'price'
name = 'XGB-1'

# %%
collection[name]= {}

hyperparams = {'max_depth':10,
               'eta':0.1,
               'gamma':0.2,
               'min_child_weight':5,
               'subsample':0.8,
               'objective':'reg:linear',
               'early_stopping_rounds':20,
               'num_round':300,
               'seed':100}

collection[name]['model'] = source.xgboost(prefix=name,
                                           data=data,
                                           W=W,
                                           target=target,
                                           hyperparams=hyperparams)

collection[name]['model'].fit()
collection[name]['model'].init_predictor()
# Out:
# 's3_input' class will be renamed to 'TrainingInput' in SageMaker Python SDK v2.
# 's3_input' class will be renamed to 'TrainingInput' in SageMaker Python SDK v2.
# 'get_image_uri' method will be deprecated in favor of 'ImageURIProvider' class in SageMaker Python SDK v2.
# There is a more up to date SageMaker XGBoost image. To use the newer image, please set 'repo_version'='1.0-1'. For example:
# 	get_image_uri(region, 'xgboost', '1.0-1').
# Parameter image_name will be renamed to image_uri in SageMaker Python SDK v2.
# 2021-02-06 11:50:24 Starting - Starting the training job...
# 2021-02-06 11:50:26 Starting - Launching requested ML instances......
# 2021-02-06 11:51:28 Starting - Preparing the instances for training......
# 2021-02-06 11:52:50 Downloading - Downloading input data
# 2021-02-06 11:52:50 Training - Downloading the training image...
# 2021-02-06 11:53:20 Uploading - Uploading generated training modelArguments: train
# [2021-02-06:11:53:10:INFO] Running standalone xgboost training.
# [2021-02-06:11:53:10:INFO] File size need to be processed in the node: 24.71mb. Available memory size in the node: 8436.97mb
# [2021-02-06:11:53:10:INFO] Determined delimiter of CSV input is ','
# [11:53:10] S3DistributionType set as FullyReplicated
# [11:53:10] 25508x35 matrix with 892780 entries loaded from /opt/ml/input/data/train?format=csv&label_column=0&delimiter=,
# [2021-02-06:11:53:10:INFO] Determined delimiter of CSV input is ','
# [11:53:10] S3DistributionType set as FullyReplicated
# [11:53:10] 13823x35 matrix with 483805 entries loaded from /opt/ml/input/data/validation?format=csv&label_column=0&delimiter=,
# [11:53:10] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 680 extra nodes, 10 pruned nodes, max_depth=10
# [0]#011train-rmse:3.09665#011validation-rmse:4.47656
# Multiple eval metrics have been passed: 'validation-rmse' will be used for early stopping.
#
# Will train until validation-rmse hasn't improved in 20 rounds.
# [11:53:11] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 592 extra nodes, 4 pruned nodes, max_depth=10
# [1]#011train-rmse:2.87747#011validation-rmse:4.3402
# [11:53:11] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 562 extra nodes, 14 pruned nodes, max_depth=10
# [2]#011train-rmse:2.69155#011validation-rmse:4.221
# [11:53:11] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 596 extra nodes, 8 pruned nodes, max_depth=10
# [3]#011train-rmse:2.51648#011validation-rmse:4.10285
# [11:53:11] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 584 extra nodes, 10 pruned nodes, max_depth=10
# [4]#011train-rmse:2.36242#011validation-rmse:3.9949
# [11:53:11] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 612 extra nodes, 8 pruned nodes, max_depth=10
# [5]#011train-rmse:2.22495#011validation-rmse:3.91397
# [11:53:11] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 520 extra nodes, 4 pruned nodes, max_depth=10
# [6]#011train-rmse:2.09882#011validation-rmse:3.83481
# [11:53:11] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 612 extra nodes, 12 pruned nodes, max_depth=10
# [7]#011train-rmse:1.99394#011validation-rmse:3.76764
# [11:53:11] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 540 extra nodes, 6 pruned nodes, max_depth=10
# [8]#011train-rmse:1.89407#011validation-rmse:3.71016
# [11:53:11] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 530 extra nodes, 8 pruned nodes, max_depth=10
# [9]#011train-rmse:1.80456#011validation-rmse:3.66133
# [11:53:11] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 580 extra nodes, 16 pruned nodes, max_depth=10
# [10]#011train-rmse:1.73554#011validation-rmse:3.61597
# [11:53:11] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 252 extra nodes, 0 pruned nodes, max_depth=10
# [11]#011train-rmse:1.66134#011validation-rmse:3.57792
# [11:53:12] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 394 extra nodes, 0 pruned nodes, max_depth=10
# [12]#011train-rmse:1.59835#011validation-rmse:3.53943
# [11:53:12] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 280 extra nodes, 2 pruned nodes, max_depth=10
# [13]#011train-rmse:1.53868#011validation-rmse:3.50119
# [11:53:12] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 160 extra nodes, 2 pruned nodes, max_depth=10
# [14]#011train-rmse:1.48499#011validation-rmse:3.46341
# [11:53:12] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 164 extra nodes, 2 pruned nodes, max_depth=10
# [15]#011train-rmse:1.43759#011validation-rmse:3.42928
# [11:53:12] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 178 extra nodes, 2 pruned nodes, max_depth=10
# [16]#011train-rmse:1.39341#011validation-rmse:3.3993
# [11:53:12] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 278 extra nodes, 0 pruned nodes, max_depth=10
# [17]#011train-rmse:1.35961#011validation-rmse:3.37732
# [11:53:12] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 152 extra nodes, 0 pruned nodes, max_depth=10
# [18]#011train-rmse:1.32509#011validation-rmse:3.35195
# [11:53:12] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 176 extra nodes, 2 pruned nodes, max_depth=10
# [19]#011train-rmse:1.29116#011validation-rmse:3.32761
# [11:53:13] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 156 extra nodes, 0 pruned nodes, max_depth=10
# [20]#011train-rmse:1.26174#011validation-rmse:3.32166
# [11:53:13] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 164 extra nodes, 2 pruned nodes, max_depth=10
# [21]#011train-rmse:1.23422#011validation-rmse:3.29078
# [11:53:13] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 114 extra nodes, 4 pruned nodes, max_depth=10
# [22]#011train-rmse:1.21202#011validation-rmse:3.28485
# [11:53:13] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 142 extra nodes, 0 pruned nodes, max_depth=10
# [23]#011train-rmse:1.17394#011validation-rmse:3.26879
# [11:53:13] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 138 extra nodes, 0 pruned nodes, max_depth=10
# [24]#011train-rmse:1.15896#011validation-rmse:3.2694
# [11:53:13] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 88 extra nodes, 0 pruned nodes, max_depth=10
# [25]#011train-rmse:1.14112#011validation-rmse:3.26873
# [11:53:13] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 80 extra nodes, 0 pruned nodes, max_depth=10
# [26]#011train-rmse:1.13348#011validation-rmse:3.26477
# [11:53:13] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 104 extra nodes, 0 pruned nodes, max_depth=10
# [27]#011train-rmse:1.11464#011validation-rmse:3.24156
# [11:53:13] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 62 extra nodes, 0 pruned nodes, max_depth=10
# [28]#011train-rmse:1.10502#011validation-rmse:3.23927
# [11:53:13] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 72 extra nodes, 0 pruned nodes, max_depth=10
# [29]#011train-rmse:1.08366#011validation-rmse:3.23756
# [11:53:14] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 104 extra nodes, 0 pruned nodes, max_depth=10
# [30]#011train-rmse:1.07094#011validation-rmse:3.2368
# [11:53:14] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 78 extra nodes, 0 pruned nodes, max_depth=10
# [31]#011train-rmse:1.06214#011validation-rmse:3.21877
# [11:53:14] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 56 extra nodes, 0 pruned nodes, max_depth=10
# [32]#011train-rmse:1.05126#011validation-rmse:3.21658
# [11:53:14] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 58 extra nodes, 0 pruned nodes, max_depth=10
# [33]#011train-rmse:1.03056#011validation-rmse:3.21547
# [11:53:14] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 42 extra nodes, 0 pruned nodes, max_depth=10
# [34]#011train-rmse:1.01639#011validation-rmse:3.21426
# [11:53:14] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 60 extra nodes, 0 pruned nodes, max_depth=10
# [35]#011train-rmse:0.997104#011validation-rmse:3.21113
# [11:53:14] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 0 pruned nodes, max_depth=10
# [36]#011train-rmse:0.984159#011validation-rmse:3.21656
# [11:53:14] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 56 extra nodes, 0 pruned nodes, max_depth=10
# [37]#011train-rmse:0.982185#011validation-rmse:3.21535
# [11:53:14] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 38 extra nodes, 0 pruned nodes, max_depth=10
# [38]#011train-rmse:0.975008#011validation-rmse:3.21769
# [11:53:14] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 44 extra nodes, 0 pruned nodes, max_depth=10
# [39]#011train-rmse:0.958165#011validation-rmse:3.21532
# [11:53:14] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 92 extra nodes, 0 pruned nodes, max_depth=10
# [40]#011train-rmse:0.937587#011validation-rmse:3.20757
# [11:53:14] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 34 extra nodes, 0 pruned nodes, max_depth=10
# [41]#011train-rmse:0.928832#011validation-rmse:3.21093
# [11:53:14] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 48 extra nodes, 0 pruned nodes, max_depth=10
# [42]#011train-rmse:0.917996#011validation-rmse:3.21064
# [11:53:15] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 32 extra nodes, 0 pruned nodes, max_depth=10
# [43]#011train-rmse:0.912576#011validation-rmse:3.21037
# [11:53:15] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 36 extra nodes, 0 pruned nodes, max_depth=10
# [44]#011train-rmse:0.90297#011validation-rmse:3.21161
# [11:53:15] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 0 pruned nodes, max_depth=10
# [45]#011train-rmse:0.890092#011validation-rmse:3.20756
# [11:53:15] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 0 pruned nodes, max_depth=10
# [46]#011train-rmse:0.88908#011validation-rmse:3.20858
# [11:53:15] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 0 pruned nodes, max_depth=10
# [47]#011train-rmse:0.880702#011validation-rmse:3.21035
# [11:53:15] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 26 extra nodes, 0 pruned nodes, max_depth=10
# [48]#011train-rmse:0.8671#011validation-rmse:3.20551
# [11:53:15] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 0 pruned nodes, max_depth=10
# [49]#011train-rmse:0.855407#011validation-rmse:3.20147
# [11:53:15] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 40 extra nodes, 0 pruned nodes, max_depth=10
# [50]#011train-rmse:0.846155#011validation-rmse:3.20115
# [11:53:15] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 36 extra nodes, 0 pruned nodes, max_depth=10
# [51]#011train-rmse:0.836956#011validation-rmse:3.2023
# [11:53:15] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 38 extra nodes, 0 pruned nodes, max_depth=10
# [52]#011train-rmse:0.825013#011validation-rmse:3.20453
# [11:53:15] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 0 pruned nodes, max_depth=10
# [53]#011train-rmse:0.817202#011validation-rmse:3.20648
# [11:53:15] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 26 extra nodes, 0 pruned nodes, max_depth=10
# [54]#011train-rmse:0.810973#011validation-rmse:3.20463
# [11:53:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 34 extra nodes, 0 pruned nodes, max_depth=10
# [55]#011train-rmse:0.808256#011validation-rmse:3.20075
# [11:53:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 0 pruned nodes, max_depth=10
# [56]#011train-rmse:0.807037#011validation-rmse:3.20349
# [11:53:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 0 pruned nodes, max_depth=10
# [57]#011train-rmse:0.800101#011validation-rmse:3.20462
# [11:53:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 0 pruned nodes, max_depth=10
# [58]#011train-rmse:0.789351#011validation-rmse:3.20807
# [11:53:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 38 extra nodes, 0 pruned nodes, max_depth=10
# [59]#011train-rmse:0.784039#011validation-rmse:3.20885
# [11:53:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 0 pruned nodes, max_depth=10
# [60]#011train-rmse:0.777169#011validation-rmse:3.20953
# [11:53:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 0 pruned nodes, max_depth=10
# [61]#011train-rmse:0.772116#011validation-rmse:3.21119
# [11:53:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 0 pruned nodes, max_depth=10
# [62]#011train-rmse:0.765294#011validation-rmse:3.21329
# [11:53:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 0 pruned nodes, max_depth=10
# [63]#011train-rmse:0.758252#011validation-rmse:3.21101
# [11:53:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 34 extra nodes, 0 pruned nodes, max_depth=10
# [64]#011train-rmse:0.752782#011validation-rmse:3.21318
# [11:53:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 0 pruned nodes, max_depth=10
# [65]#011train-rmse:0.747709#011validation-rmse:3.20582
# [11:53:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 0 pruned nodes, max_depth=10
# [66]#011train-rmse:0.744209#011validation-rmse:3.20336
# [11:53:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 0 pruned nodes, max_depth=10
# [67]#011train-rmse:0.739839#011validation-rmse:3.20155
# [11:53:17] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 40 extra nodes, 2 pruned nodes, max_depth=10
# [68]#011train-rmse:0.732453#011validation-rmse:3.20435
# [11:53:17] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 0 pruned nodes, max_depth=10
# [69]#011train-rmse:0.729121#011validation-rmse:3.205
# [11:53:17] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 40 extra nodes, 0 pruned nodes, max_depth=10
# [70]#011train-rmse:0.72458#011validation-rmse:3.20918
# [11:53:17] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 32 extra nodes, 0 pruned nodes, max_depth=10
# [71]#011train-rmse:0.720774#011validation-rmse:3.21162
# [11:53:17] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 26 extra nodes, 0 pruned nodes, max_depth=10
# [72]#011train-rmse:0.717853#011validation-rmse:3.21434
# [11:53:17] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 0 pruned nodes, max_depth=10
# [73]#011train-rmse:0.712797#011validation-rmse:3.21769
# [11:53:17] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 0 pruned nodes, max_depth=10
# [74]#011train-rmse:0.707479#011validation-rmse:3.21906
# [11:53:17] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 0 pruned nodes, max_depth=10
# [75]#011train-rmse:0.698732#011validation-rmse:3.22249
# Stopping. Best iteration:
# [55]#011train-rmse:0.808256#011validation-rmse:3.20075
#
#
# 2021-02-06 11:53:27 Completed - Training job completed
# Parameter image will be renamed to image_uri in SageMaker Python SDK v2.
# Training seconds: 60
# Billable seconds: 60
# -------------!

# %%
trainval = collection[name]['model'].sets['trainval']['ori'].copy()
trainval.set_index('time', drop=True, inplace=True)
collection[name]['trainval'] = trainval

test_result = collection[name]['model'].predict('test', unscaled=False)
collection[name]['test'] = test_result

test_result_unscaled = collection[name].predict('test', unscaled=True)
collection[name]['test_unscaled'] = test_result_unscaled
# Out:
# ---------------------------------------------------------------------------
# ValidationError                           Traceback (most recent call last)
# <ipython-input-171-0b5b4ce21393> in <module>
#       2 trainval.set_index('time', drop=True, inplace=True)
#       3
# ----> 4 test_result = collection[name].predict('test', unscaled=False)
#       5 test_result_unscaled = collection[name].predict('test', unscaled=True)
#       6 trade_result = source.metric.evaluate(test_result_unscaled, target)
#
# ~/SageMaker/crypto-prediction/source/xgboost.py in predict(self, predict_set, unscaled, batch_size)
#      83         val_input = sagemaker.s3_input(s3_data=val_location, content_type='text/csv')
#      84
# ---> 85         container = get_image_uri(self.session.boto_region_name, 'xgboost')
#      86
#      87         xgb = Estimator(container,
#
# ~/SageMaker/crypto-prediction/source/xgboost.py in <listcomp>(.0)
#      83         val_input = sagemaker.s3_input(s3_data=val_location, content_type='text/csv')
#      84
# ---> 85         container = get_image_uri(self.session.boto_region_name, 'xgboost')
#      86
#      87         xgb = Estimator(container,
#
# ~/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages/sagemaker/predictor.py in predict(self, data, initial_args, target_model, target_variant)
#     111
#     112         request_args = self._create_request_args(data, initial_args, target_model, target_variant)
# --> 113         response = self.sagemaker_session.sagemaker_runtime_client.invoke_endpoint(**request_args)
#     114         return self._handle_response(response)
#     115
#
# ~/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages/botocore/client.py in _api_call(self, *args, **kwargs)
#     355                     "%s() only accepts keyword arguments." % py_operation_name)
#     356             # The "self" in this scope is referring to the BaseClient.
# --> 357             return self._make_api_call(operation_name, kwargs)
#     358
#     359         _api_call.__name__ = str(py_operation_name)
#
# ~/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages/botocore/client.py in _make_api_call(self, operation_name, api_params)
#     674             error_code = parsed_response.get("Error", {}).get("Code")
#     675             error_class = self.exceptions.from_code(error_code)
# --> 676             raise error_class(parsed_response, operation_name)
#     677         else:
#     678             return parsed_response
#
# ValidationError: An error occurred (ValidationError) when calling the InvokeEndpoint operation: Endpoint xgboost-2021-02-06-11-50-24-402 of account 937637726599 not found.

# %%
collection[name]['test_unscaled']
trade_result = source.metric.trade(collection[name]['test_unscaled'], target)
print('RMSE: ', RMSE(collection[name]['test_unscaled']))

# %%
source.plot.plot_results({"Test": collection[name]['test']}, 'BTC Price (Scaled) - ' + name, 'BTC')

# %%
source.plot.plot_results({"Train": collection[name]['trainval'], 'Test': collection[name]['test_unscaled']}, 'BTC Price (Unscaled) - ' + name, 'BTC', scale='log')

# %%
source.plot.plot_history({name: trade_result}, 'Trading Result - ' + name)

# %%
collection[name].cleanup()

# %% [markdown]
# <h5> --- XGBoost Iteration 2 [XGB-2]</h5>

# %%
W = 7
target = 'price'
name = 'XGB-2'

# %%
hyperparams = {'max_depth':10,
               'eta':0.1,
               'gamma':0.2,
               'min_child_weight':15,
               'subsample':0.8,
               'objective':'reg:linear',
               'early_stopping_rounds':20,
               'num_round':300,
               'seed':100}

collection[name] = source.xgboost(prefix=name,
                                  data=data,
                                  W=W,
                                  target=target,
                                  hyperparams=hyperparams)

collection[name].fit()
collection[name].init_predictor()
# Out:
# 's3_input' class will be renamed to 'TrainingInput' in SageMaker Python SDK v2.
# 's3_input' class will be renamed to 'TrainingInput' in SageMaker Python SDK v2.
# 'get_image_uri' method will be deprecated in favor of 'ImageURIProvider' class in SageMaker Python SDK v2.
# There is a more up to date SageMaker XGBoost image. To use the newer image, please set 'repo_version'='1.0-1'. For example:
# 	get_image_uri(region, 'xgboost', '1.0-1').
# Parameter image_name will be renamed to image_uri in SageMaker Python SDK v2.
# 2021-02-06 13:31:13 Starting - Starting the training job...
# 2021-02-06 13:31:15 Starting - Launching requested ML instances......
# 2021-02-06 13:32:18 Starting - Preparing the instances for training...
# 2021-02-06 13:33:11 Downloading - Downloading input data...
# 2021-02-06 13:33:34 Training - Downloading the training image..Arguments: train
# [2021-02-06:13:33:54:INFO] Running standalone xgboost training.
# [2021-02-06:13:33:54:INFO] File size need to be processed in the node: 34.59mb. Available memory size in the node: 8443.61mb
# [2021-02-06:13:33:54:INFO] Determined delimiter of CSV input is ','
# [13:33:54] S3DistributionType set as FullyReplicated
# [13:33:54] 25263x49 matrix with 1237887 entries loaded from /opt/ml/input/data/train?format=csv&label_column=0&delimiter=,
# [2021-02-06:13:33:54:INFO] Determined delimiter of CSV input is ','
# [13:33:54] S3DistributionType set as FullyReplicated
# [13:33:54] 13802x49 matrix with 676298 entries loaded from /opt/ml/input/data/validation?format=csv&label_column=0&delimiter=,
# [13:33:54] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 616 extra nodes, 6 pruned nodes, max_depth=10
# [0]#011train-rmse:1.9785#011validation-rmse:2.18493
# Multiple eval metrics have been passed: 'validation-rmse' will be used for early stopping.
#
# Will train until validation-rmse hasn't improved in 20 rounds.
# [13:33:54] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 598 extra nodes, 4 pruned nodes, max_depth=10
# [1]#011train-rmse:1.82344#011validation-rmse:2.05807
# [13:33:54] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 580 extra nodes, 16 pruned nodes, max_depth=10
# [2]#011train-rmse:1.68032#011validation-rmse:1.94234
# [13:33:54] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 612 extra nodes, 16 pruned nodes, max_depth=10
# [3]#011train-rmse:1.5547#011validation-rmse:1.84194
# [13:33:55] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 620 extra nodes, 28 pruned nodes, max_depth=10
# [4]#011train-rmse:1.44557#011validation-rmse:1.75838
# [13:33:55] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 608 extra nodes, 34 pruned nodes, max_depth=10
# [5]#011train-rmse:1.34341#011validation-rmse:1.68527
# [13:33:55] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 546 extra nodes, 32 pruned nodes, max_depth=10
# [6]#011train-rmse:1.25304#011validation-rmse:1.61597
# [13:33:55] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 652 extra nodes, 52 pruned nodes, max_depth=10
# [7]#011train-rmse:1.17284#011validation-rmse:1.56186
# [13:33:55] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 614 extra nodes, 44 pruned nodes, max_depth=10
# [8]#011train-rmse:1.10281#011validation-rmse:1.51869
# [13:33:55] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 626 extra nodes, 38 pruned nodes, max_depth=10
# [9]#011train-rmse:1.04096#011validation-rmse:1.48132
# [13:33:55] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 596 extra nodes, 52 pruned nodes, max_depth=10
# [10]#011train-rmse:0.985702#011validation-rmse:1.44463
# [13:33:56] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 574 extra nodes, 30 pruned nodes, max_depth=10
# [11]#011train-rmse:0.936002#011validation-rmse:1.4162
# [13:33:56] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 442 extra nodes, 26 pruned nodes, max_depth=10
# [12]#011train-rmse:0.891791#011validation-rmse:1.3843
# [13:33:56] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 480 extra nodes, 22 pruned nodes, max_depth=10
# [13]#011train-rmse:0.850137#011validation-rmse:1.36171
# [13:33:56] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 548 extra nodes, 84 pruned nodes, max_depth=10
# [14]#011train-rmse:0.815248#011validation-rmse:1.33743
# [13:33:56] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 484 extra nodes, 60 pruned nodes, max_depth=10
# [15]#011train-rmse:0.784654#011validation-rmse:1.31689
# [13:33:56] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 496 extra nodes, 28 pruned nodes, max_depth=10
# [16]#011train-rmse:0.757724#011validation-rmse:1.29794
# [13:33:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 420 extra nodes, 16 pruned nodes, max_depth=10
# [17]#011train-rmse:0.73298#011validation-rmse:1.27902
# [13:33:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 410 extra nodes, 26 pruned nodes, max_depth=10
# [18]#011train-rmse:0.708326#011validation-rmse:1.27131
# [13:33:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 548 extra nodes, 120 pruned nodes, max_depth=10
# [19]#011train-rmse:0.689386#011validation-rmse:1.26045
# [13:33:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 322 extra nodes, 6 pruned nodes, max_depth=10
# [20]#011train-rmse:0.672217#011validation-rmse:1.24687
# [13:33:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 440 extra nodes, 64 pruned nodes, max_depth=10
# [21]#011train-rmse:0.658818#011validation-rmse:1.23818
# [13:33:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 372 extra nodes, 32 pruned nodes, max_depth=10
# [22]#011train-rmse:0.641829#011validation-rmse:1.22712
# [13:33:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 296 extra nodes, 14 pruned nodes, max_depth=10
# [23]#011train-rmse:0.627189#011validation-rmse:1.22152
# [13:33:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 308 extra nodes, 30 pruned nodes, max_depth=10
# [24]#011train-rmse:0.616914#011validation-rmse:1.2123
# [13:33:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 220 extra nodes, 12 pruned nodes, max_depth=10
# [25]#011train-rmse:0.607726#011validation-rmse:1.20756
# [13:33:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 310 extra nodes, 28 pruned nodes, max_depth=10
# [26]#011train-rmse:0.595247#011validation-rmse:1.20439
# [13:33:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 206 extra nodes, 26 pruned nodes, max_depth=10
# [27]#011train-rmse:0.586616#011validation-rmse:1.20543
# [13:33:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 238 extra nodes, 32 pruned nodes, max_depth=10
# [28]#011train-rmse:0.579837#011validation-rmse:1.19917
# [13:33:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 160 extra nodes, 4 pruned nodes, max_depth=10
# [29]#011train-rmse:0.573524#011validation-rmse:1.1946
# [13:33:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 256 extra nodes, 30 pruned nodes, max_depth=10
# [30]#011train-rmse:0.564074#011validation-rmse:1.19786
# [13:33:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 186 extra nodes, 40 pruned nodes, max_depth=10
# [31]#011train-rmse:0.55869#011validation-rmse:1.1926
# [13:33:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 174 extra nodes, 10 pruned nodes, max_depth=10
# [32]#011train-rmse:0.55418#011validation-rmse:1.18671
# [13:33:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 140 extra nodes, 0 pruned nodes, max_depth=10
# [33]#011train-rmse:0.550249#011validation-rmse:1.18395
# [13:33:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 114 extra nodes, 6 pruned nodes, max_depth=10
# [34]#011train-rmse:0.547433#011validation-rmse:1.18058
# [13:33:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 140 extra nodes, 0 pruned nodes, max_depth=10
# [35]#011train-rmse:0.544067#011validation-rmse:1.17689
# [13:33:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 132 extra nodes, 6 pruned nodes, max_depth=10
# [36]#011train-rmse:0.53911#011validation-rmse:1.17585
# [13:33:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 132 extra nodes, 4 pruned nodes, max_depth=10
# [37]#011train-rmse:0.535916#011validation-rmse:1.17165
# [13:33:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 112 extra nodes, 4 pruned nodes, max_depth=10
# [38]#011train-rmse:0.533514#011validation-rmse:1.16844
# [13:33:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 134 extra nodes, 4 pruned nodes, max_depth=10
# [39]#011train-rmse:0.530367#011validation-rmse:1.1703
# [13:33:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 78 extra nodes, 0 pruned nodes, max_depth=10
# [40]#011train-rmse:0.527483#011validation-rmse:1.17045
# [13:34:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 80 extra nodes, 2 pruned nodes, max_depth=10
# [41]#011train-rmse:0.525298#011validation-rmse:1.16963
# [13:34:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 116 extra nodes, 2 pruned nodes, max_depth=10
# [42]#011train-rmse:0.522798#011validation-rmse:1.16572
# [13:34:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 0 pruned nodes, max_depth=10
# [43]#011train-rmse:0.520302#011validation-rmse:1.16444
# [13:34:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 88 extra nodes, 10 pruned nodes, max_depth=10
# [44]#011train-rmse:0.518476#011validation-rmse:1.16186
# [13:34:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 92 extra nodes, 6 pruned nodes, max_depth=10
# [45]#011train-rmse:0.516522#011validation-rmse:1.16086
# [13:34:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 50 extra nodes, 2 pruned nodes, max_depth=10
# [46]#011train-rmse:0.51509#011validation-rmse:1.15981
# [13:34:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 40 extra nodes, 0 pruned nodes, max_depth=10
# [47]#011train-rmse:0.513852#011validation-rmse:1.15924
# [13:34:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 50 extra nodes, 0 pruned nodes, max_depth=10
# [48]#011train-rmse:0.512593#011validation-rmse:1.15799
# [13:34:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 34 extra nodes, 0 pruned nodes, max_depth=10
# [49]#011train-rmse:0.511375#011validation-rmse:1.15913
# [13:34:01] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 36 extra nodes, 0 pruned nodes, max_depth=10
# [50]#011train-rmse:0.509939#011validation-rmse:1.15831
# [13:34:01] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 32 extra nodes, 0 pruned nodes, max_depth=10
# [51]#011train-rmse:0.509719#011validation-rmse:1.15951
# [13:34:01] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 72 extra nodes, 0 pruned nodes, max_depth=10
# [52]#011train-rmse:0.506857#011validation-rmse:1.15678
# [13:34:01] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 54 extra nodes, 0 pruned nodes, max_depth=10
# [53]#011train-rmse:0.502355#011validation-rmse:1.16053
# [13:34:01] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 0 pruned nodes, max_depth=10
# [54]#011train-rmse:0.501253#011validation-rmse:1.15694
#
# 2021-02-06 13:34:14 Uploading - Uploading generated training model[13:34:01] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 74 extra nodes, 2 pruned nodes, max_depth=10
# [55]#011train-rmse:0.500192#011validation-rmse:1.15627
# [13:34:01] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 26 extra nodes, 0 pruned nodes, max_depth=10
# [56]#011train-rmse:0.499016#011validation-rmse:1.15814
# [13:34:02] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 0 pruned nodes, max_depth=10
# [57]#011train-rmse:0.498523#011validation-rmse:1.15699
# [13:34:02] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 0 pruned nodes, max_depth=10
# [58]#011train-rmse:0.496864#011validation-rmse:1.15637
# [13:34:02] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 34 extra nodes, 2 pruned nodes, max_depth=10
# [59]#011train-rmse:0.496405#011validation-rmse:1.15529
# [13:34:02] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 0 pruned nodes, max_depth=10
# [60]#011train-rmse:0.495721#011validation-rmse:1.15341
# [13:34:02] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 2 pruned nodes, max_depth=10
# [61]#011train-rmse:0.4958#011validation-rmse:1.15244
# [13:34:02] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 32 extra nodes, 2 pruned nodes, max_depth=10
# [62]#011train-rmse:0.494322#011validation-rmse:1.15195
# [13:34:02] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 0 pruned nodes, max_depth=10
# [63]#011train-rmse:0.493923#011validation-rmse:1.15117
# [13:34:02] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 0 pruned nodes, max_depth=10
# [64]#011train-rmse:0.493407#011validation-rmse:1.14981
# [13:34:03] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 32 extra nodes, 0 pruned nodes, max_depth=10
# [65]#011train-rmse:0.492856#011validation-rmse:1.14894
# [13:34:03] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 60 extra nodes, 0 pruned nodes, max_depth=10
# [66]#011train-rmse:0.491411#011validation-rmse:1.14585
# [13:34:03] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 40 extra nodes, 10 pruned nodes, max_depth=10
# [67]#011train-rmse:0.490566#011validation-rmse:1.14564
# [13:34:03] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 26 extra nodes, 0 pruned nodes, max_depth=10
# [68]#011train-rmse:0.489075#011validation-rmse:1.14467
# [13:34:03] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 36 extra nodes, 0 pruned nodes, max_depth=10
# [69]#011train-rmse:0.488103#011validation-rmse:1.14571
# [13:34:03] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 46 extra nodes, 0 pruned nodes, max_depth=10
# [70]#011train-rmse:0.484791#011validation-rmse:1.14336
# [13:34:03] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 32 extra nodes, 0 pruned nodes, max_depth=10
# [71]#011train-rmse:0.48415#011validation-rmse:1.1425
# [13:34:04] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 0 pruned nodes, max_depth=10
# [72]#011train-rmse:0.482541#011validation-rmse:1.14179
# [13:34:04] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 32 extra nodes, 2 pruned nodes, max_depth=10
# [73]#011train-rmse:0.482043#011validation-rmse:1.14244
# [13:34:04] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 40 extra nodes, 2 pruned nodes, max_depth=10
# [74]#011train-rmse:0.481243#011validation-rmse:1.13929
# [13:34:04] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 38 extra nodes, 2 pruned nodes, max_depth=10
# [75]#011train-rmse:0.476781#011validation-rmse:1.13153
# [13:34:04] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 42 extra nodes, 6 pruned nodes, max_depth=10
# [76]#011train-rmse:0.475929#011validation-rmse:1.13047
# [13:34:04] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 32 extra nodes, 2 pruned nodes, max_depth=10
# [77]#011train-rmse:0.475611#011validation-rmse:1.12967
# [13:34:04] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 0 pruned nodes, max_depth=10
# [78]#011train-rmse:0.475048#011validation-rmse:1.12816
# [13:34:05] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 0 pruned nodes, max_depth=10
# [79]#011train-rmse:0.474555#011validation-rmse:1.12743
# [13:34:05] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 4 pruned nodes, max_depth=10
# [80]#011train-rmse:0.47404#011validation-rmse:1.1279
# [13:34:05] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 0 pruned nodes, max_depth=10
# [81]#011train-rmse:0.472525#011validation-rmse:1.1273
# [13:34:05] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 26 extra nodes, 2 pruned nodes, max_depth=10
# [82]#011train-rmse:0.472#011validation-rmse:1.12687
# [13:34:05] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 2 pruned nodes, max_depth=10
# [83]#011train-rmse:0.471768#011validation-rmse:1.12523
# [13:34:05] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 40 extra nodes, 0 pruned nodes, max_depth=10
# [84]#011train-rmse:0.471263#011validation-rmse:1.12427
# [13:34:05] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 2 pruned nodes, max_depth=10
# [85]#011train-rmse:0.470888#011validation-rmse:1.12521
# [13:34:06] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 0 pruned nodes, max_depth=10
# [86]#011train-rmse:0.47054#011validation-rmse:1.12615
# [13:34:06] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 0 pruned nodes, max_depth=10
# [87]#011train-rmse:0.470222#011validation-rmse:1.12853
# [13:34:06] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 40 extra nodes, 0 pruned nodes, max_depth=10
# [88]#011train-rmse:0.469708#011validation-rmse:1.12921
# [13:34:06] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 26 extra nodes, 0 pruned nodes, max_depth=10
# [89]#011train-rmse:0.469287#011validation-rmse:1.12912
# [13:34:06] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 54 extra nodes, 0 pruned nodes, max_depth=10
# [90]#011train-rmse:0.467251#011validation-rmse:1.12843
# [13:34:06] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 0 pruned nodes, max_depth=10
# [91]#011train-rmse:0.466732#011validation-rmse:1.12933
# [13:34:06] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 48 extra nodes, 0 pruned nodes, max_depth=10
# [92]#011train-rmse:0.466145#011validation-rmse:1.12843
# [13:34:06] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 0 pruned nodes, max_depth=10
# [93]#011train-rmse:0.465674#011validation-rmse:1.12433
# [13:34:06] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 32 extra nodes, 0 pruned nodes, max_depth=10
# [94]#011train-rmse:0.465424#011validation-rmse:1.12458
# [13:34:06] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 32 extra nodes, 0 pruned nodes, max_depth=10
# [95]#011train-rmse:0.464816#011validation-rmse:1.1235
# [13:34:07] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 32 extra nodes, 0 pruned nodes, max_depth=10
# [96]#011train-rmse:0.464417#011validation-rmse:1.12429
# [13:34:07] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 0 pruned nodes, max_depth=10
# [97]#011train-rmse:0.463379#011validation-rmse:1.12519
# [13:34:07] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 32 extra nodes, 0 pruned nodes, max_depth=10
# [98]#011train-rmse:0.462042#011validation-rmse:1.12527
# [13:34:07] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 0 pruned nodes, max_depth=10
# [99]#011train-rmse:0.460719#011validation-rmse:1.12478
# [13:34:07] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 0 pruned nodes, max_depth=10
# [100]#011train-rmse:0.460477#011validation-rmse:1.1256
# [13:34:07] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 34 extra nodes, 10 pruned nodes, max_depth=10
# [101]#011train-rmse:0.459177#011validation-rmse:1.12697
# [13:34:07] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 32 extra nodes, 0 pruned nodes, max_depth=10
# [102]#011train-rmse:0.455956#011validation-rmse:1.12703
# [13:34:07] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 40 extra nodes, 2 pruned nodes, max_depth=10
# [103]#011train-rmse:0.455343#011validation-rmse:1.12649
# [13:34:07] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 26 extra nodes, 0 pruned nodes, max_depth=10
# [104]#011train-rmse:0.454916#011validation-rmse:1.12623
# [13:34:08] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 34 extra nodes, 0 pruned nodes, max_depth=10
# [105]#011train-rmse:0.454248#011validation-rmse:1.12661
# [13:34:08] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 2 pruned nodes, max_depth=10
# [106]#011train-rmse:0.454069#011validation-rmse:1.12881
# [13:34:08] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 2 pruned nodes, max_depth=10
# [107]#011train-rmse:0.453611#011validation-rmse:1.12764
# [13:34:08] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 0 pruned nodes, max_depth=10
# [108]#011train-rmse:0.452767#011validation-rmse:1.12923
# [13:34:08] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 2 pruned nodes, max_depth=10
# [109]#011train-rmse:0.452367#011validation-rmse:1.12961
# [13:34:08] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 26 extra nodes, 2 pruned nodes, max_depth=10
# [110]#011train-rmse:0.452113#011validation-rmse:1.12904
# [13:34:08] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 0 pruned nodes, max_depth=10
# [111]#011train-rmse:0.450947#011validation-rmse:1.13043
# [13:34:08] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 38 extra nodes, 0 pruned nodes, max_depth=10
# [112]#011train-rmse:0.449729#011validation-rmse:1.13044
# [13:34:08] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 34 extra nodes, 0 pruned nodes, max_depth=10
# [113]#011train-rmse:0.449235#011validation-rmse:1.12887
# [13:34:08] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 26 extra nodes, 0 pruned nodes, max_depth=10
# [114]#011train-rmse:0.448822#011validation-rmse:1.12946
# [13:34:09] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 0 pruned nodes, max_depth=10
# [115]#011train-rmse:0.448672#011validation-rmse:1.12898
# Stopping. Best iteration:
# [95]#011train-rmse:0.464816#011validation-rmse:1.1235
#
#
# 2021-02-06 13:34:21 Completed - Training job completed
# Parameter image will be renamed to image_uri in SageMaker Python SDK v2.
# Training seconds: 70
# Billable seconds: 70
# ---------------!

# %%
trainval = collection[name].sets['trainval']['ori'].copy()
trainval.set_index('time', drop=True, inplace=True)

test_result = collection[name].predict('test', unscaled=False)
test_result_unscaled = collection[name].predict('test', unscaled=True)
trade_result = source.metric.trade(test_result_unscaled, target)

# %%
print('RMSE: ', RMSE(test_result))

# %%
source.plot.plot_results({"Test": test_result}, 'BTC Price (Scaled) - ' + name, 'BTC')

# %%
source.plot.plot_results({"Train": trainval, 'Test': test_result_unscaled}, 'BTC Price (Unscaled) - ' + name, 'BTC', scale='log')

# %%
source.plot.plot_history({name: trade_result}, 'Trading Result -' + name)

# %%
collection[name].cleanup()

# %% [markdown]
# <h5> --- XGBoost Iteration 3 [XGB-3]</h5>

# %%
W = 5
target = 'price'
name = 'XGB-3'

# %%
hyperparams = {'max_depth':20,
               'eta':0.1,
               'gamma':0.2,
               'min_child_weight':5,
               'subsample':0.8,
               'objective':'reg:linear',
               'early_stopping_rounds':20,
               'num_round':300,
               'seed':100}

collection[name] = source.xgboost(prefix=name,
                                  data=data,
                                  W=W,
                                  target=target,
                                  hyperparams=hyperparams)

collection[name].fit()
collection[name].init_predictor()
# Out:
# 's3_input' class will be renamed to 'TrainingInput' in SageMaker Python SDK v2.
# 's3_input' class will be renamed to 'TrainingInput' in SageMaker Python SDK v2.
# 'get_image_uri' method will be deprecated in favor of 'ImageURIProvider' class in SageMaker Python SDK v2.
# There is a more up to date SageMaker XGBoost image. To use the newer image, please set 'repo_version'='1.0-1'. For example:
# 	get_image_uri(region, 'xgboost', '1.0-1').
# Parameter image_name will be renamed to image_uri in SageMaker Python SDK v2.
# 2021-02-06 13:42:42 Starting - Starting the training job...
# 2021-02-06 13:42:45 Starting - Launching requested ML instances......
# 2021-02-06 13:43:50 Starting - Preparing the instances for training...
# 2021-02-06 13:44:43 Downloading - Downloading input data......
# 2021-02-06 13:45:36 Training - Training image download completed. Training in progress..Arguments: train
# [2021-02-06:13:45:37:INFO] Running standalone xgboost training.
# [2021-02-06:13:45:37:INFO] File size need to be processed in the node: 24.45mb. Available memory size in the node: 8423.62mb
# [2021-02-06:13:45:37:INFO] Determined delimiter of CSV input is ','
# [13:45:37] S3DistributionType set as FullyReplicated
# [13:45:37] 25088x35 matrix with 878080 entries loaded from /opt/ml/input/data/train?format=csv&label_column=0&delimiter=,
# [2021-02-06:13:45:37:INFO] Determined delimiter of CSV input is ','
# [13:45:37] S3DistributionType set as FullyReplicated
# [13:45:37] 13787x35 matrix with 482545 entries loaded from /opt/ml/input/data/validation?format=csv&label_column=0&delimiter=,
# [13:45:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 1722 extra nodes, 398 pruned nodes, max_depth=20
# [0]#011train-rmse:2.72899#011validation-rmse:5.39411
# Multiple eval metrics have been passed: 'validation-rmse' will be used for early stopping.
#
# Will train until validation-rmse hasn't improved in 20 rounds.
# [13:45:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 1692 extra nodes, 460 pruned nodes, max_depth=20
# [1]#011train-rmse:2.51009#011validation-rmse:5.27258
# [13:45:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 1686 extra nodes, 478 pruned nodes, max_depth=20
# [2]#011train-rmse:2.31838#011validation-rmse:5.17222
# [13:45:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 1660 extra nodes, 580 pruned nodes, max_depth=20
# [3]#011train-rmse:2.14309#011validation-rmse:5.07835
# [13:45:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 1642 extra nodes, 698 pruned nodes, max_depth=20
# [4]#011train-rmse:1.98595#011validation-rmse:5.0037
# [13:45:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 1586 extra nodes, 732 pruned nodes, max_depth=20
# [5]#011train-rmse:1.84562#011validation-rmse:4.93886
# [13:45:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 1598 extra nodes, 794 pruned nodes, max_depth=20
# [6]#011train-rmse:1.71645#011validation-rmse:4.8734
# [13:45:39] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 1606 extra nodes, 890 pruned nodes, max_depth=20
# [7]#011train-rmse:1.60105#011validation-rmse:4.82907
# [13:45:39] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 1512 extra nodes, 980 pruned nodes, max_depth=20
# [8]#011train-rmse:1.503#011validation-rmse:4.783
# [13:45:39] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 1512 extra nodes, 1100 pruned nodes, max_depth=20
# [9]#011train-rmse:1.41075#011validation-rmse:4.74898
# [13:45:39] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 1462 extra nodes, 1304 pruned nodes, max_depth=20
# [10]#011train-rmse:1.32717#011validation-rmse:4.71143
# [13:45:40] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 1442 extra nodes, 1298 pruned nodes, max_depth=20
# [11]#011train-rmse:1.25112#011validation-rmse:4.67978
# [13:45:40] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 1398 extra nodes, 1354 pruned nodes, max_depth=20
# [12]#011train-rmse:1.18168#011validation-rmse:4.6501
# [13:45:40] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 1334 extra nodes, 1530 pruned nodes, max_depth=20
# [13]#011train-rmse:1.12595#011validation-rmse:4.62986
# [13:45:40] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 1378 extra nodes, 1740 pruned nodes, max_depth=20
# [14]#011train-rmse:1.07053#011validation-rmse:4.60056
# [13:45:40] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 1254 extra nodes, 1776 pruned nodes, max_depth=20
# [15]#011train-rmse:1.02137#011validation-rmse:4.58293
# [13:45:40] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 1236 extra nodes, 1746 pruned nodes, max_depth=20
# [16]#011train-rmse:0.977816#011validation-rmse:4.56198
# [13:45:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 1184 extra nodes, 1814 pruned nodes, max_depth=20
# [17]#011train-rmse:0.934039#011validation-rmse:4.55215
# [13:45:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 1182 extra nodes, 2196 pruned nodes, max_depth=20
# [18]#011train-rmse:0.896869#011validation-rmse:4.5399
# [13:45:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 1172 extra nodes, 2092 pruned nodes, max_depth=20
# [19]#011train-rmse:0.858769#011validation-rmse:4.53027
# [13:45:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 1086 extra nodes, 2122 pruned nodes, max_depth=20
# [20]#011train-rmse:0.826957#011validation-rmse:4.52262
# [13:45:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 1050 extra nodes, 2490 pruned nodes, max_depth=20
# [21]#011train-rmse:0.796131#011validation-rmse:4.51142
# [13:45:42] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 996 extra nodes, 2242 pruned nodes, max_depth=20
# [22]#011train-rmse:0.769984#011validation-rmse:4.49479
# [13:45:42] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 994 extra nodes, 2520 pruned nodes, max_depth=20
# [23]#011train-rmse:0.746958#011validation-rmse:4.48513
# [13:45:42] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 926 extra nodes, 2650 pruned nodes, max_depth=20
# [24]#011train-rmse:0.726792#011validation-rmse:4.48095
# [13:45:42] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 834 extra nodes, 1938 pruned nodes, max_depth=20
# [25]#011train-rmse:0.70655#011validation-rmse:4.46967
# [13:45:42] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 810 extra nodes, 1986 pruned nodes, max_depth=20
# [26]#011train-rmse:0.687808#011validation-rmse:4.46356
# [13:45:42] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 802 extra nodes, 2080 pruned nodes, max_depth=20
# [27]#011train-rmse:0.672229#011validation-rmse:4.46055
# [13:45:43] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 748 extra nodes, 1642 pruned nodes, max_depth=20
# [28]#011train-rmse:0.657252#011validation-rmse:4.45795
# [13:45:43] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 726 extra nodes, 1862 pruned nodes, max_depth=20
# [29]#011train-rmse:0.64341#011validation-rmse:4.45525
# [13:45:43] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 680 extra nodes, 1566 pruned nodes, max_depth=20
# [30]#011train-rmse:0.626929#011validation-rmse:4.44747
# [13:45:43] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 666 extra nodes, 1336 pruned nodes, max_depth=20
# [31]#011train-rmse:0.616136#011validation-rmse:4.44557
# [13:45:43] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 544 extra nodes, 1330 pruned nodes, max_depth=20
# [32]#011train-rmse:0.601594#011validation-rmse:4.44288
# [13:45:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 510 extra nodes, 730 pruned nodes, max_depth=20
# [33]#011train-rmse:0.587989#011validation-rmse:4.44365
# [13:45:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 494 extra nodes, 406 pruned nodes, max_depth=20
# [34]#011train-rmse:0.578201#011validation-rmse:4.43801
# [13:45:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 488 extra nodes, 652 pruned nodes, max_depth=20
# [35]#011train-rmse:0.565758#011validation-rmse:4.42973
# [13:45:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 514 extra nodes, 836 pruned nodes, max_depth=20
# [36]#011train-rmse:0.555775#011validation-rmse:4.43149
# [13:45:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 350 extra nodes, 98 pruned nodes, max_depth=20
# [37]#011train-rmse:0.546686#011validation-rmse:4.43147
# [13:45:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 416 extra nodes, 462 pruned nodes, max_depth=20
# [38]#011train-rmse:0.537442#011validation-rmse:4.42862
# [13:45:45] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 394 extra nodes, 280 pruned nodes, max_depth=20
# [39]#011train-rmse:0.529154#011validation-rmse:4.42455
# [13:45:45] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 160 extra nodes, 6 pruned nodes, max_depth=20
# [40]#011train-rmse:0.520617#011validation-rmse:4.42241
# [13:45:45] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 314 extra nodes, 74 pruned nodes, max_depth=20
# [41]#011train-rmse:0.513675#011validation-rmse:4.4186
# [13:45:45] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 454 extra nodes, 526 pruned nodes, max_depth=20
# [42]#011train-rmse:0.507164#011validation-rmse:4.41433
# [13:45:45] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 392 extra nodes, 368 pruned nodes, max_depth=20
# [43]#011train-rmse:0.501286#011validation-rmse:4.41204
# [13:45:45] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 236 extra nodes, 20 pruned nodes, max_depth=20
# [44]#011train-rmse:0.496858#011validation-rmse:4.40894
# [13:45:45] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 296 extra nodes, 62 pruned nodes, max_depth=20
# [45]#011train-rmse:0.486585#011validation-rmse:4.40763
# [13:45:46] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 292 extra nodes, 54 pruned nodes, max_depth=20
# [46]#011train-rmse:0.47732#011validation-rmse:4.40666
# [13:45:46] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 178 extra nodes, 24 pruned nodes, max_depth=20
# [47]#011train-rmse:0.473055#011validation-rmse:4.40469
# [13:45:46] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 282 extra nodes, 84 pruned nodes, max_depth=20
# [48]#011train-rmse:0.466287#011validation-rmse:4.40478
# [13:45:46] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 126 extra nodes, 4 pruned nodes, max_depth=20
# [49]#011train-rmse:0.461145#011validation-rmse:4.40636
# [13:45:46] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 102 extra nodes, 2 pruned nodes, max_depth=20
# [50]#011train-rmse:0.454575#011validation-rmse:4.40897
# [13:45:46] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 228 extra nodes, 48 pruned nodes, max_depth=20
# [51]#011train-rmse:0.450106#011validation-rmse:4.40976
# [13:45:47] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 96 extra nodes, 2 pruned nodes, max_depth=20
# [52]#011train-rmse:0.444813#011validation-rmse:4.40637
# [13:45:47] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 86 extra nodes, 0 pruned nodes, max_depth=20
# [53]#011train-rmse:0.439342#011validation-rmse:4.40569
# [13:45:47] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 100 extra nodes, 6 pruned nodes, max_depth=20
# [54]#011train-rmse:0.434401#011validation-rmse:4.41005
# [13:45:47] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 170 extra nodes, 32 pruned nodes, max_depth=20
# [55]#011train-rmse:0.429001#011validation-rmse:4.40957
# [13:45:47] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 118 extra nodes, 8 pruned nodes, max_depth=20
# [56]#011train-rmse:0.425985#011validation-rmse:4.41219
# [13:45:47] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 88 extra nodes, 4 pruned nodes, max_depth=20
# [57]#011train-rmse:0.422561#011validation-rmse:4.41133
# [13:45:47] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 134 extra nodes, 14 pruned nodes, max_depth=20
# [58]#011train-rmse:0.417238#011validation-rmse:4.41235
# [13:45:48] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 92 extra nodes, 2 pruned nodes, max_depth=20
# [59]#011train-rmse:0.411563#011validation-rmse:4.40772
# [13:45:48] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 86 extra nodes, 0 pruned nodes, max_depth=20
# [60]#011train-rmse:0.408401#011validation-rmse:4.40925
# [13:45:48] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 66 extra nodes, 4 pruned nodes, max_depth=20
# [61]#011train-rmse:0.402313#011validation-rmse:4.40966
# [13:45:48] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 66 extra nodes, 0 pruned nodes, max_depth=20
# [62]#011train-rmse:0.397398#011validation-rmse:4.40796
# [13:45:48] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 78 extra nodes, 2 pruned nodes, max_depth=20
# [63]#011train-rmse:0.393026#011validation-rmse:4.40728
# [13:45:48] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 84 extra nodes, 2 pruned nodes, max_depth=20
# [64]#011train-rmse:0.387257#011validation-rmse:4.40706
# [13:45:48] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 102 extra nodes, 14 pruned nodes, max_depth=20
# [65]#011train-rmse:0.383318#011validation-rmse:4.40872
# [13:45:49] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 82 extra nodes, 2 pruned nodes, max_depth=20
# [66]#011train-rmse:0.378984#011validation-rmse:4.41287
# [13:45:49] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 88 extra nodes, 8 pruned nodes, max_depth=20
# [67]#011train-rmse:0.374869#011validation-rmse:4.4099
# Stopping. Best iteration:
# [47]#011train-rmse:0.473055#011validation-rmse:4.40469
#
#
# 2021-02-06 13:45:59 Uploading - Uploading generated training model
# 2021-02-06 13:45:59 Completed - Training job completed
# Parameter image will be renamed to image_uri in SageMaker Python SDK v2.
# Training seconds: 76
# Billable seconds: 76
# -------------!

# %%
trainval = collection[name].sets['trainval']['ori'].copy()
trainval.set_index('time', drop=True, inplace=True)

test_result = collection[name].predict('test', unscaled=False)
test_result_unscaled = collection[name].predict('test', unscaled=True)
trade_result = source.metric.trade(test_result_unscaled, target)

# %%
print('RMSE: ', RMSE(test_result))

# %%
source.plot.plot_results({"Test": test_result}, 'BTC Price (Scaled) - ' + name, 'BTC')

# %%
source.plot.plot_results({"Train": trainval, 'Test': test_result_unscaled}, 'BTC Price (Unscaled) - ' + name, 'BTC', scale='log')

# %%
source.plot.plot_history({name: trade_result}, 'Trading Result - ' + name)

# %%
collection[name].cleanup()

# %% [markdown]
# <h5> --- XGBoost Iteration 4 [XGB-4]</h5>

# %%
W = 7
target = 'price'
name = 'XGB-4'

# %%
hyperparams = {'max_depth':20,
               'eta':0.1,
               'gamma':0.2,
               'min_child_weight':15,
               'subsample':0.8,
               'objective':'reg:linear',
               'early_stopping_rounds':20,
               'num_round':300,
               'seed':100}

collection[name] = source.xgboost(prefix=name,
                                  data=data,
                                  W=W,
                                  target=target,
                                  hyperparams=hyperparams)

collection[name].fit()
collection[name].init_predictor()
# Out:
# 's3_input' class will be renamed to 'TrainingInput' in SageMaker Python SDK v2.
# 's3_input' class will be renamed to 'TrainingInput' in SageMaker Python SDK v2.
# 'get_image_uri' method will be deprecated in favor of 'ImageURIProvider' class in SageMaker Python SDK v2.
# There is a more up to date SageMaker XGBoost image. To use the newer image, please set 'repo_version'='1.0-1'. For example:
# 	get_image_uri(region, 'xgboost', '1.0-1').
# Parameter image_name will be renamed to image_uri in SageMaker Python SDK v2.
# 2021-02-06 13:53:11 Starting - Starting the training job...
# 2021-02-06 13:53:14 Starting - Launching requested ML instances......
# 2021-02-06 13:54:16 Starting - Preparing the instances for training......
# 2021-02-06 13:55:22 Downloading - Downloading input data...
# 2021-02-06 13:55:55 Training - Downloading the training image..Arguments: train
# [2021-02-06:13:56:15:INFO] Running standalone xgboost training.
# [2021-02-06:13:56:15:INFO] File size need to be processed in the node: 34.21mb. Available memory size in the node: 8425.64mb
# [2021-02-06:13:56:15:INFO] Determined delimiter of CSV input is ','
# [13:56:15] S3DistributionType set as FullyReplicated
# [13:56:15] 24844x49 matrix with 1217356 entries loaded from /opt/ml/input/data/train?format=csv&label_column=0&delimiter=,
# [2021-02-06:13:56:15:INFO] Determined delimiter of CSV input is ','
# [13:56:15] S3DistributionType set as FullyReplicated
# [13:56:15] 13765x49 matrix with 674485 entries loaded from /opt/ml/input/data/validation?format=csv&label_column=0&delimiter=,
# [13:56:15] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 978 extra nodes, 90 pruned nodes, max_depth=17
# [0]#011train-rmse:1.98979#011validation-rmse:2.19213
# Multiple eval metrics have been passed: 'validation-rmse' will be used for early stopping.
#
# Will train until validation-rmse hasn't improved in 20 rounds.
# [13:56:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 1028 extra nodes, 122 pruned nodes, max_depth=19
# [1]#011train-rmse:1.83036#011validation-rmse:2.05793
# [13:56:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 1010 extra nodes, 144 pruned nodes, max_depth=17
# [2]#011train-rmse:1.68724#011validation-rmse:1.94264
# [13:56:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 1020 extra nodes, 158 pruned nodes, max_depth=19
# [3]#011train-rmse:1.56058#011validation-rmse:1.84383
# [13:56:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 1048 extra nodes, 160 pruned nodes, max_depth=17
# [4]#011train-rmse:1.44679#011validation-rmse:1.7571
# [13:56:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 1010 extra nodes, 248 pruned nodes, max_depth=17
# [5]#011train-rmse:1.34555#011validation-rmse:1.68241
# [13:56:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 1018 extra nodes, 250 pruned nodes, max_depth=17
# [6]#011train-rmse:1.25584#011validation-rmse:1.61739
# [13:56:17] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 1006 extra nodes, 290 pruned nodes, max_depth=18
# [7]#011train-rmse:1.17403#011validation-rmse:1.55358
# [13:56:17] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 1016 extra nodes, 270 pruned nodes, max_depth=20
# [8]#011train-rmse:1.10417#011validation-rmse:1.50446
# [13:56:17] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 1010 extra nodes, 388 pruned nodes, max_depth=19
# [9]#011train-rmse:1.03916#011validation-rmse:1.45969
# [13:56:17] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 1010 extra nodes, 384 pruned nodes, max_depth=20
# [10]#011train-rmse:0.982491#011validation-rmse:1.42694
# [13:56:17] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 978 extra nodes, 452 pruned nodes, max_depth=20
# [11]#011train-rmse:0.929946#011validation-rmse:1.38882
# [13:56:18] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 918 extra nodes, 506 pruned nodes, max_depth=20
# [12]#011train-rmse:0.886187#011validation-rmse:1.36128
# [13:56:18] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 974 extra nodes, 568 pruned nodes, max_depth=17
# [13]#011train-rmse:0.849875#011validation-rmse:1.3389
# [13:56:18] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 918 extra nodes, 598 pruned nodes, max_depth=20
# [14]#011train-rmse:0.812168#011validation-rmse:1.31296
# [13:56:18] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 896 extra nodes, 638 pruned nodes, max_depth=20
# [15]#011train-rmse:0.782685#011validation-rmse:1.29326
# [13:56:18] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 898 extra nodes, 678 pruned nodes, max_depth=20
# [16]#011train-rmse:0.75182#011validation-rmse:1.27471
# [13:56:19] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 828 extra nodes, 780 pruned nodes, max_depth=20
# [17]#011train-rmse:0.726645#011validation-rmse:1.26363
# [13:56:19] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 830 extra nodes, 816 pruned nodes, max_depth=20
# [18]#011train-rmse:0.703645#011validation-rmse:1.24709
# [13:56:19] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 772 extra nodes, 906 pruned nodes, max_depth=19
# [19]#011train-rmse:0.68617#011validation-rmse:1.23883
# [13:56:19] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 772 extra nodes, 860 pruned nodes, max_depth=20
# [20]#011train-rmse:0.668178#011validation-rmse:1.22534
# [13:56:19] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 706 extra nodes, 932 pruned nodes, max_depth=20
# [21]#011train-rmse:0.654243#011validation-rmse:1.21552
# [13:56:20] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 714 extra nodes, 962 pruned nodes, max_depth=20
# [22]#011train-rmse:0.64207#011validation-rmse:1.20712
# [13:56:20] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 658 extra nodes, 940 pruned nodes, max_depth=20
# [23]#011train-rmse:0.629345#011validation-rmse:1.2008
# [13:56:20] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 638 extra nodes, 896 pruned nodes, max_depth=20
# [24]#011train-rmse:0.619973#011validation-rmse:1.19551
# [13:56:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 634 extra nodes, 1068 pruned nodes, max_depth=20
# [25]#011train-rmse:0.610936#011validation-rmse:1.18863
# [13:56:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 604 extra nodes, 1124 pruned nodes, max_depth=20
# [26]#011train-rmse:0.598764#011validation-rmse:1.18669
# [13:56:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 616 extra nodes, 1018 pruned nodes, max_depth=20
# [27]#011train-rmse:0.587272#011validation-rmse:1.18413
# [13:56:22] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 536 extra nodes, 1112 pruned nodes, max_depth=20
# [28]#011train-rmse:0.580518#011validation-rmse:1.17971
# [13:56:22] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 544 extra nodes, 1154 pruned nodes, max_depth=20
# [29]#011train-rmse:0.574766#011validation-rmse:1.17346
# [13:56:22] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 520 extra nodes, 1136 pruned nodes, max_depth=20
# [30]#011train-rmse:0.569601#011validation-rmse:1.17034
# [13:56:22] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 502 extra nodes, 1052 pruned nodes, max_depth=20
# [31]#011train-rmse:0.56494#011validation-rmse:1.16826
# [13:56:23] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 450 extra nodes, 1038 pruned nodes, max_depth=20
# [32]#011train-rmse:0.560076#011validation-rmse:1.1686
# [13:56:23] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 444 extra nodes, 942 pruned nodes, max_depth=20
# [33]#011train-rmse:0.555786#011validation-rmse:1.16623
# [13:56:23] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 466 extra nodes, 1176 pruned nodes, max_depth=20
# [34]#011train-rmse:0.549014#011validation-rmse:1.169
# [13:56:23] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 406 extra nodes, 766 pruned nodes, max_depth=20
# [35]#011train-rmse:0.545374#011validation-rmse:1.16692
# [13:56:23] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 386 extra nodes, 1022 pruned nodes, max_depth=20
# [36]#011train-rmse:0.538882#011validation-rmse:1.16915
# [13:56:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 394 extra nodes, 960 pruned nodes, max_depth=20
# [37]#011train-rmse:0.535449#011validation-rmse:1.16684
# [13:56:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 346 extra nodes, 766 pruned nodes, max_depth=20
# [38]#011train-rmse:0.531586#011validation-rmse:1.16555
# [13:56:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 356 extra nodes, 1146 pruned nodes, max_depth=20
# [39]#011train-rmse:0.527866#011validation-rmse:1.16336
# [13:56:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 304 extra nodes, 556 pruned nodes, max_depth=20
# [40]#011train-rmse:0.525341#011validation-rmse:1.16225
# [13:56:25] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 288 extra nodes, 598 pruned nodes, max_depth=20
# [41]#011train-rmse:0.522769#011validation-rmse:1.16406
# [13:56:25] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 290 extra nodes, 466 pruned nodes, max_depth=20
# [42]#011train-rmse:0.520682#011validation-rmse:1.16231
# [13:56:25] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 210 extra nodes, 212 pruned nodes, max_depth=20
# [43]#011train-rmse:0.514681#011validation-rmse:1.16634
# [13:56:25] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 352 extra nodes, 958 pruned nodes, max_depth=20
# [44]#011train-rmse:0.511194#011validation-rmse:1.16435
# [13:56:26] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 238 extra nodes, 292 pruned nodes, max_depth=20
# [45]#011train-rmse:0.508475#011validation-rmse:1.16316
# [13:56:26] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 194 extra nodes, 128 pruned nodes, max_depth=20
# [46]#011train-rmse:0.506285#011validation-rmse:1.16176
# [13:56:26] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 200 extra nodes, 146 pruned nodes, max_depth=20
# [47]#011train-rmse:0.501725#011validation-rmse:1.15353
# [13:56:26] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 184 extra nodes, 178 pruned nodes, max_depth=20
# [48]#011train-rmse:0.499472#011validation-rmse:1.15194
# [13:56:26] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 152 extra nodes, 48 pruned nodes, max_depth=20
# [49]#011train-rmse:0.496883#011validation-rmse:1.15162
# [13:56:27] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 138 extra nodes, 94 pruned nodes, max_depth=20
# [50]#011train-rmse:0.495645#011validation-rmse:1.15062
# [13:56:27] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 150 extra nodes, 94 pruned nodes, max_depth=20
# [51]#011train-rmse:0.493959#011validation-rmse:1.14887
# [13:56:27] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 88 extra nodes, 6 pruned nodes, max_depth=20
# [52]#011train-rmse:0.493087#011validation-rmse:1.15024
# [13:56:27] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 70 extra nodes, 44 pruned nodes, max_depth=20
# [53]#011train-rmse:0.492234#011validation-rmse:1.149
# [13:56:27] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 180 extra nodes, 88 pruned nodes, max_depth=20
# [54]#011train-rmse:0.490519#011validation-rmse:1.14853
#
# 2021-02-06 13:56:40 Uploading - Uploading generated training model[13:56:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 92 extra nodes, 16 pruned nodes, max_depth=20
# [55]#011train-rmse:0.488765#011validation-rmse:1.14596
# [13:56:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 134 extra nodes, 64 pruned nodes, max_depth=20
# [56]#011train-rmse:0.48823#011validation-rmse:1.14707
# [13:56:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 114 extra nodes, 54 pruned nodes, max_depth=20
# [57]#011train-rmse:0.486367#011validation-rmse:1.14879
# [13:56:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 78 extra nodes, 22 pruned nodes, max_depth=20
# [58]#011train-rmse:0.485209#011validation-rmse:1.1457
# [13:56:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 66 extra nodes, 6 pruned nodes, max_depth=20
# [59]#011train-rmse:0.484256#011validation-rmse:1.14477
# [13:56:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 54 extra nodes, 16 pruned nodes, max_depth=20
# [60]#011train-rmse:0.481397#011validation-rmse:1.1486
# [13:56:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 60 extra nodes, 6 pruned nodes, max_depth=20
# [61]#011train-rmse:0.480401#011validation-rmse:1.15089
# [13:56:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 104 extra nodes, 76 pruned nodes, max_depth=20
# [62]#011train-rmse:0.479303#011validation-rmse:1.14716
# [13:56:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 122 extra nodes, 86 pruned nodes, max_depth=20
# [63]#011train-rmse:0.477984#011validation-rmse:1.14538
# [13:56:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 114 extra nodes, 54 pruned nodes, max_depth=20
# [64]#011train-rmse:0.477308#011validation-rmse:1.14431
# [13:56:30] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 76 extra nodes, 4 pruned nodes, max_depth=20
# [65]#011train-rmse:0.476764#011validation-rmse:1.14441
# [13:56:30] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 72 extra nodes, 8 pruned nodes, max_depth=20
# [66]#011train-rmse:0.475869#011validation-rmse:1.14309
# [13:56:30] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 108 extra nodes, 28 pruned nodes, max_depth=20
# [67]#011train-rmse:0.473836#011validation-rmse:1.14177
# [13:56:30] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 56 extra nodes, 2 pruned nodes, max_depth=20
# [68]#011train-rmse:0.473172#011validation-rmse:1.14092
# [13:56:31] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 136 extra nodes, 90 pruned nodes, max_depth=20
# [69]#011train-rmse:0.472563#011validation-rmse:1.13949
# [13:56:31] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 98 extra nodes, 22 pruned nodes, max_depth=20
# [70]#011train-rmse:0.472007#011validation-rmse:1.13877
# [13:56:31] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 74 extra nodes, 4 pruned nodes, max_depth=20
# [71]#011train-rmse:0.47108#011validation-rmse:1.14076
# [13:56:31] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 62 extra nodes, 6 pruned nodes, max_depth=20
# [72]#011train-rmse:0.470008#011validation-rmse:1.14018
# [13:56:31] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 84 extra nodes, 20 pruned nodes, max_depth=20
# [73]#011train-rmse:0.468213#011validation-rmse:1.14
# [13:56:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 60 extra nodes, 0 pruned nodes, max_depth=20
# [74]#011train-rmse:0.467434#011validation-rmse:1.1391
# [13:56:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 50 extra nodes, 8 pruned nodes, max_depth=20
# [75]#011train-rmse:0.466724#011validation-rmse:1.13664
# [13:56:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 62 extra nodes, 4 pruned nodes, max_depth=20
# [76]#011train-rmse:0.465468#011validation-rmse:1.13489
# [13:56:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 102 extra nodes, 74 pruned nodes, max_depth=20
# [77]#011train-rmse:0.464337#011validation-rmse:1.13392
# [13:56:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 140 extra nodes, 34 pruned nodes, max_depth=20
# [78]#011train-rmse:0.463468#011validation-rmse:1.13351
# [13:56:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 80 extra nodes, 22 pruned nodes, max_depth=20
# [79]#011train-rmse:0.462745#011validation-rmse:1.13333
# [13:56:33] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 72 extra nodes, 12 pruned nodes, max_depth=20
# [80]#011train-rmse:0.462202#011validation-rmse:1.13318
# [13:56:33] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 80 extra nodes, 12 pruned nodes, max_depth=20
# [81]#011train-rmse:0.461069#011validation-rmse:1.13302
# [13:56:33] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 78 extra nodes, 30 pruned nodes, max_depth=20
# [82]#011train-rmse:0.459855#011validation-rmse:1.1325
# [13:56:33] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 142 extra nodes, 48 pruned nodes, max_depth=20
# [83]#011train-rmse:0.459202#011validation-rmse:1.1321
# [13:56:33] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 88 extra nodes, 12 pruned nodes, max_depth=20
# [84]#011train-rmse:0.458873#011validation-rmse:1.13127
# [13:56:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 66 extra nodes, 22 pruned nodes, max_depth=20
# [85]#011train-rmse:0.458321#011validation-rmse:1.13157
# [13:56:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 92 extra nodes, 26 pruned nodes, max_depth=20
# [86]#011train-rmse:0.456418#011validation-rmse:1.13079
# [13:56:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 58 extra nodes, 2 pruned nodes, max_depth=20
# [87]#011train-rmse:0.455815#011validation-rmse:1.13044
# [13:56:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 94 extra nodes, 68 pruned nodes, max_depth=20
# [88]#011train-rmse:0.455616#011validation-rmse:1.13149
# [13:56:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 84 extra nodes, 50 pruned nodes, max_depth=20
# [89]#011train-rmse:0.454536#011validation-rmse:1.13258
# [13:56:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 100 extra nodes, 88 pruned nodes, max_depth=20
# [90]#011train-rmse:0.45364#011validation-rmse:1.13207
# [13:56:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 72 extra nodes, 8 pruned nodes, max_depth=20
# [91]#011train-rmse:0.453099#011validation-rmse:1.13065
# [13:56:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 52 extra nodes, 4 pruned nodes, max_depth=20
# [92]#011train-rmse:0.450101#011validation-rmse:1.13613
# [13:56:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 82 extra nodes, 24 pruned nodes, max_depth=20
# [93]#011train-rmse:0.449634#011validation-rmse:1.13671
# [13:56:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 50 extra nodes, 16 pruned nodes, max_depth=16
# [94]#011train-rmse:0.445224#011validation-rmse:1.13542
# [13:56:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 64 extra nodes, 16 pruned nodes, max_depth=20
# [95]#011train-rmse:0.44484#011validation-rmse:1.1348
# [13:56:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 74 extra nodes, 54 pruned nodes, max_depth=20
# [96]#011train-rmse:0.444583#011validation-rmse:1.13598
# [13:56:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 64 extra nodes, 14 pruned nodes, max_depth=20
# [97]#011train-rmse:0.443272#011validation-rmse:1.13744
# [13:56:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 74 extra nodes, 48 pruned nodes, max_depth=20
# [98]#011train-rmse:0.442788#011validation-rmse:1.13691
# [13:56:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 56 extra nodes, 10 pruned nodes, max_depth=19
# [99]#011train-rmse:0.442911#011validation-rmse:1.13965
# [13:56:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 82 extra nodes, 2 pruned nodes, max_depth=20
# [100]#011train-rmse:0.44229#011validation-rmse:1.13856
# [13:56:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 60 extra nodes, 4 pruned nodes, max_depth=20
# [101]#011train-rmse:0.44195#011validation-rmse:1.13923
# [13:56:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 100 extra nodes, 24 pruned nodes, max_depth=20
# [102]#011train-rmse:0.440314#011validation-rmse:1.13883
# [13:56:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 40 extra nodes, 20 pruned nodes, max_depth=16
# [103]#011train-rmse:0.439914#011validation-rmse:1.13656
# [13:56:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 82 extra nodes, 46 pruned nodes, max_depth=20
# [104]#011train-rmse:0.43859#011validation-rmse:1.13539
# [13:56:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 52 extra nodes, 14 pruned nodes, max_depth=17
# [105]#011train-rmse:0.437972#011validation-rmse:1.13377
# [13:56:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 62 extra nodes, 6 pruned nodes, max_depth=20
# [106]#011train-rmse:0.437169#011validation-rmse:1.13358
# [13:56:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 80 extra nodes, 20 pruned nodes, max_depth=20
# [107]#011train-rmse:0.43665#011validation-rmse:1.13345
# Stopping. Best iteration:
# [87]#011train-rmse:0.455815#011validation-rmse:1.13044
#
#
# 2021-02-06 13:56:47 Completed - Training job completed
# Parameter image will be renamed to image_uri in SageMaker Python SDK v2.
# Training seconds: 85
# Billable seconds: 85
# -------------!

# %%
trainval = collection[name].sets['trainval']['ori'].copy()
trainval.set_index('time', drop=True, inplace=True)

test_result = collection[name].predict('test', unscaled=False)
test_result_unscaled = collection[name].predict('test', unscaled=True)
trade_result = source.metric.trade(test_result_unscaled, target)

# %%
print('RMSE: ', RMSE(test_result))

# %%
source.plot.plot_results({"Test": test_result}, 'BTC Price (Scaled) - ' + name, 'BTC')

# %%
source.plot.plot_results({"Train": trainval, 'Test': test_result_unscaled}, 'BTC Price (Unscaled) - ' + name, 'BTC', scale='log')

# %%
source.plot.plot_history({name: trade_result}, 'Trading Result -' + name)

# %%
collection[name].cleanup()

# %% [markdown]
# <h2> Neural Net Evaluation </h2>

# %% [markdown]
# <h5> --- Neural Net Iteration 1 [NN-1]</h5>

# %%
W = 5
target = 'price'
name = 'NN-1'

# %%
hyperparams = {'hidden_layers': 50,
               'max_iter': 10000,
               'random_state': 100}
               
collection[name] = source.neuralnet(prefix=name,
                        data=data,
                        W=W,
                        target=target,
                        hyperparams=hyperparams)

collection[name].fit()
collection[name].init_predictor()
# Out:
# 's3_input' class will be renamed to 'TrainingInput' in SageMaker Python SDK v2.
# 's3_input' class will be renamed to 'TrainingInput' in SageMaker Python SDK v2.
# 2021-02-06 14:04:11 Starting - Starting the training job...
# 2021-02-06 14:04:13 Starting - Launching requested ML instances......
# 2021-02-06 14:05:34 Starting - Preparing the instances for training...............
# 2021-02-06 14:08:11 Downloading - Downloading input data
# 2021-02-06 14:08:11 Training - Downloading the training image...
# 2021-02-06 14:08:24 Training - Training image download completed. Training in progress....2021-02-06 14:08:26,341 sagemaker-containers INFO     Imported framework sagemaker_sklearn_container.training
# 2021-02-06 14:08:26,344 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# 2021-02-06 14:08:26,354 sagemaker_sklearn_container.training INFO     Invoking user training script.
# 2021-02-06 14:08:26,844 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# 2021-02-06 14:08:29,890 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# 2021-02-06 14:08:29,903 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# 2021-02-06 14:08:29,913 sagemaker-training-toolkit INFO     Invoking user script
#
# Training Env:
#
# {
#     "additional_framework_parameters": {},
#     "channel_input_dirs": {
#         "validation": "/opt/ml/input/data/validation",
#         "train": "/opt/ml/input/data/train"
#     },
#     "current_host": "algo-1",
#     "framework_module": "sagemaker_sklearn_container.training:main",
#     "hosts": [
#         "algo-1"
#     ],
#     "hyperparameters": {
#         "max_iter": 10000,
#         "hidden_layers": 50
#     },
#     "input_config_dir": "/opt/ml/input/config",
#     "input_data_config": {
#         "validation": {
#             "TrainingInputMode": "File",
#             "S3DistributionType": "FullyReplicated",
#             "RecordWrapperType": "None"
#         },
#         "train": {
#             "TrainingInputMode": "File",
#             "S3DistributionType": "FullyReplicated",
#             "RecordWrapperType": "None"
#         }
#     },
#     "input_dir": "/opt/ml/input",
#     "is_master": true,
#     "job_name": "sagemaker-scikit-learn-2021-02-06-14-04-11-165",
#     "log_level": 20,
#     "master_hostname": "algo-1",
#     "model_dir": "/opt/ml/model",
#     "module_dir": "s3://sagemaker-us-east-2-937637726599/sagemaker-scikit-learn-2021-02-06-14-04-11-165/source/sourcedir.tar.gz",
#     "module_name": "train",
#     "network_interface_name": "eth0",
#     "num_cpus": 4,
#     "num_gpus": 0,
#     "output_data_dir": "/opt/ml/output/data",
#     "output_dir": "/opt/ml/output",
#     "output_intermediate_dir": "/opt/ml/output/intermediate",
#     "resource_config": {
#         "current_host": "algo-1",
#         "hosts": [
#             "algo-1"
#         ],
#         "network_interface_name": "eth0"
#     },
#     "user_entry_point": "train.py"
# }
#
# Environment variables:
#
# SM_HOSTS=["algo-1"]
# SM_NETWORK_INTERFACE_NAME=eth0
# SM_HPS={"hidden_layers":50,"max_iter":10000}
# SM_USER_ENTRY_POINT=train.py
# SM_FRAMEWORK_PARAMS={}
# SM_RESOURCE_CONFIG={"current_host":"algo-1","hosts":["algo-1"],"network_interface_name":"eth0"}
# SM_INPUT_DATA_CONFIG={"train":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"},"validation":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}}
# SM_OUTPUT_DATA_DIR=/opt/ml/output/data
# SM_CHANNELS=["train","validation"]
# SM_CURRENT_HOST=algo-1
# SM_MODULE_NAME=train
# SM_LOG_LEVEL=20
# SM_FRAMEWORK_MODULE=sagemaker_sklearn_container.training:main
# SM_INPUT_DIR=/opt/ml/input
# SM_INPUT_CONFIG_DIR=/opt/ml/input/config
# SM_OUTPUT_DIR=/opt/ml/output
# SM_NUM_CPUS=4
# SM_NUM_GPUS=0
# SM_MODEL_DIR=/opt/ml/model
# SM_MODULE_DIR=s3://sagemaker-us-east-2-937637726599/sagemaker-scikit-learn-2021-02-06-14-04-11-165/source/sourcedir.tar.gz
# SM_TRAINING_ENV={"additional_framework_parameters":{},"channel_input_dirs":{"train":"/opt/ml/input/data/train","validation":"/opt/ml/input/data/validation"},"current_host":"algo-1","framework_module":"sagemaker_sklearn_container.training:main","hosts":["algo-1"],"hyperparameters":{"hidden_layers":50,"max_iter":10000},"input_config_dir":"/opt/ml/input/config","input_data_config":{"train":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"},"validation":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}},"input_dir":"/opt/ml/input","is_master":true,"job_name":"sagemaker-scikit-learn-2021-02-06-14-04-11-165","log_level":20,"master_hostname":"algo-1","model_dir":"/opt/ml/model","module_dir":"s3://sagemaker-us-east-2-937637726599/sagemaker-scikit-learn-2021-02-06-14-04-11-165/source/sourcedir.tar.gz","module_name":"train","network_interface_name":"eth0","num_cpus":4,"num_gpus":0,"output_data_dir":"/opt/ml/output/data","output_dir":"/opt/ml/output","output_intermediate_dir":"/opt/ml/output/intermediate","resource_config":{"current_host":"algo-1","hosts":["algo-1"],"network_interface_name":"eth0"},"user_entry_point":"train.py"}
# SM_USER_ARGS=["--hidden_layers","50","--max_iter","10000"]
# SM_OUTPUT_INTERMEDIATE_DIR=/opt/ml/output/intermediate
# SM_CHANNEL_VALIDATION=/opt/ml/input/data/validation
# SM_CHANNEL_TRAIN=/opt/ml/input/data/train
# SM_HP_MAX_ITER=10000
# SM_HP_HIDDEN_LAYERS=50
# PYTHONPATH=/opt/ml/code:/miniconda3/bin:/miniconda3/lib/python37.zip:/miniconda3/lib/python3.7:/miniconda3/lib/python3.7/lib-dynload:/miniconda3/lib/python3.7/site-packages
#
# Invoking script with the following command:
#
# /miniconda3/bin/python train.py --hidden_layers 50 --max_iter 10000
#
#
# 2021-02-06 14:10:54,928 sagemaker-containers INFO     Reporting training SUCCESS
#
# 2021-02-06 14:11:07 Uploading - Uploading generated training model
# 2021-02-06 14:11:07 Completed - Training job completed
# Parameter image will be renamed to image_uri in SageMaker Python SDK v2.
# Training seconds: 184
# Billable seconds: 184
# -------------!

# %%
trainval = collection[name].sets['trainval']['ori'].copy()
trainval.set_index('time', drop=True, inplace=True)

test_result = collection[name].predict('test', unscaled=False)
test_result_unscaled = collection[name].predict('test', unscaled=True)
trade_result = source.metric.trade(test_result_unscaled, target)

# %%
print('RMSE: ', RMSE(test_result))

# %%
source.plot.plot_results({"Test": test_result}, 'BTC Price (Scaled) - ' + name, 'BTC')

# %%
source.plot.plot_results({"Train": trainval, 'Test': test_result_unscaled}, 'BTC Price (Unscaled) - ' + name, 'BTC', scale='log')

# %%
source.plot.plot_history({name: trade_result}, 'Trading Result - ' + name)

# %%
collection[name].cleanup()

# %% [markdown]
# <h5> --- Neural Net Iteration 2 [NN-2]</h5>

# %%
W = 7
target = 'price'
name = 'NN-2'

# %%
hyperparams = {'hidden_layers': 50,
               'max_iter': 10000,
               'random_state': 100}
               
collection[name] = source.neuralnet(prefix=name,
                        data=data,
                        W=W,
                        target=target,
                        hyperparams=hyperparams)

collection[name].fit()
collection[name].init_predictor()
# Out:
# 's3_input' class will be renamed to 'TrainingInput' in SageMaker Python SDK v2.
# 's3_input' class will be renamed to 'TrainingInput' in SageMaker Python SDK v2.
# 2021-02-06 14:18:13 Starting - Starting the training job...
# 2021-02-06 14:18:15 Starting - Launching requested ML instances......
# 2021-02-06 14:19:16 Starting - Preparing the instances for training...
# 2021-02-06 14:20:05 Downloading - Downloading input data...
# 2021-02-06 14:20:40 Training - Downloading the training image...
# 2021-02-06 14:20:55 Training - Training image download completed. Training in progress....2021-02-06 14:20:56,069 sagemaker-containers INFO     Imported framework sagemaker_sklearn_container.training
# 2021-02-06 14:20:56,072 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# 2021-02-06 14:20:56,082 sagemaker_sklearn_container.training INFO     Invoking user training script.
# 2021-02-06 14:20:56,433 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# 2021-02-06 14:20:57,088 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# 2021-02-06 14:20:57,100 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# 2021-02-06 14:20:57,110 sagemaker-training-toolkit INFO     Invoking user script
#
# Training Env:
#
# {
#     "additional_framework_parameters": {},
#     "channel_input_dirs": {
#         "validation": "/opt/ml/input/data/validation",
#         "train": "/opt/ml/input/data/train"
#     },
#     "current_host": "algo-1",
#     "framework_module": "sagemaker_sklearn_container.training:main",
#     "hosts": [
#         "algo-1"
#     ],
#     "hyperparameters": {
#         "max_iter": 10000,
#         "hidden_layers": 50
#     },
#     "input_config_dir": "/opt/ml/input/config",
#     "input_data_config": {
#         "validation": {
#             "TrainingInputMode": "File",
#             "S3DistributionType": "FullyReplicated",
#             "RecordWrapperType": "None"
#         },
#         "train": {
#             "TrainingInputMode": "File",
#             "S3DistributionType": "FullyReplicated",
#             "RecordWrapperType": "None"
#         }
#     },
#     "input_dir": "/opt/ml/input",
#     "is_master": true,
#     "job_name": "sagemaker-scikit-learn-2021-02-06-14-18-12-961",
#     "log_level": 20,
#     "master_hostname": "algo-1",
#     "model_dir": "/opt/ml/model",
#     "module_dir": "s3://sagemaker-us-east-2-937637726599/sagemaker-scikit-learn-2021-02-06-14-18-12-961/source/sourcedir.tar.gz",
#     "module_name": "train",
#     "network_interface_name": "eth0",
#     "num_cpus": 4,
#     "num_gpus": 0,
#     "output_data_dir": "/opt/ml/output/data",
#     "output_dir": "/opt/ml/output",
#     "output_intermediate_dir": "/opt/ml/output/intermediate",
#     "resource_config": {
#         "current_host": "algo-1",
#         "hosts": [
#             "algo-1"
#         ],
#         "network_interface_name": "eth0"
#     },
#     "user_entry_point": "train.py"
# }
#
# Environment variables:
#
# SM_HOSTS=["algo-1"]
# SM_NETWORK_INTERFACE_NAME=eth0
# SM_HPS={"hidden_layers":50,"max_iter":10000}
# SM_USER_ENTRY_POINT=train.py
# SM_FRAMEWORK_PARAMS={}
# SM_RESOURCE_CONFIG={"current_host":"algo-1","hosts":["algo-1"],"network_interface_name":"eth0"}
# SM_INPUT_DATA_CONFIG={"train":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"},"validation":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}}
# SM_OUTPUT_DATA_DIR=/opt/ml/output/data
# SM_CHANNELS=["train","validation"]
# SM_CURRENT_HOST=algo-1
# SM_MODULE_NAME=train
# SM_LOG_LEVEL=20
# SM_FRAMEWORK_MODULE=sagemaker_sklearn_container.training:main
# SM_INPUT_DIR=/opt/ml/input
# SM_INPUT_CONFIG_DIR=/opt/ml/input/config
# SM_OUTPUT_DIR=/opt/ml/output
# SM_NUM_CPUS=4
# SM_NUM_GPUS=0
# SM_MODEL_DIR=/opt/ml/model
# SM_MODULE_DIR=s3://sagemaker-us-east-2-937637726599/sagemaker-scikit-learn-2021-02-06-14-18-12-961/source/sourcedir.tar.gz
# SM_TRAINING_ENV={"additional_framework_parameters":{},"channel_input_dirs":{"train":"/opt/ml/input/data/train","validation":"/opt/ml/input/data/validation"},"current_host":"algo-1","framework_module":"sagemaker_sklearn_container.training:main","hosts":["algo-1"],"hyperparameters":{"hidden_layers":50,"max_iter":10000},"input_config_dir":"/opt/ml/input/config","input_data_config":{"train":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"},"validation":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}},"input_dir":"/opt/ml/input","is_master":true,"job_name":"sagemaker-scikit-learn-2021-02-06-14-18-12-961","log_level":20,"master_hostname":"algo-1","model_dir":"/opt/ml/model","module_dir":"s3://sagemaker-us-east-2-937637726599/sagemaker-scikit-learn-2021-02-06-14-18-12-961/source/sourcedir.tar.gz","module_name":"train","network_interface_name":"eth0","num_cpus":4,"num_gpus":0,"output_data_dir":"/opt/ml/output/data","output_dir":"/opt/ml/output","output_intermediate_dir":"/opt/ml/output/intermediate","resource_config":{"current_host":"algo-1","hosts":["algo-1"],"network_interface_name":"eth0"},"user_entry_point":"train.py"}
# SM_USER_ARGS=["--hidden_layers","50","--max_iter","10000"]
# SM_OUTPUT_INTERMEDIATE_DIR=/opt/ml/output/intermediate
# SM_CHANNEL_VALIDATION=/opt/ml/input/data/validation
# SM_CHANNEL_TRAIN=/opt/ml/input/data/train
# SM_HP_MAX_ITER=10000
# SM_HP_HIDDEN_LAYERS=50
# PYTHONPATH=/opt/ml/code:/miniconda3/bin:/miniconda3/lib/python37.zip:/miniconda3/lib/python3.7:/miniconda3/lib/python3.7/lib-dynload:/miniconda3/lib/python3.7/site-packages
#
# Invoking script with the following command:
#
# /miniconda3/bin/python train.py --hidden_layers 50 --max_iter 10000
#
#
#
# 2021-02-06 14:24:43 Uploading - Uploading generated training model
# 2021-02-06 14:24:43 Completed - Training job completed
# 2021-02-06 14:24:34,116 sagemaker-containers INFO     Reporting training SUCCESS
# Parameter image will be renamed to image_uri in SageMaker Python SDK v2.
# Training seconds: 278
# Billable seconds: 278
# -------------!

# %%
trainval = collection[name].sets['trainval']['ori'].copy()
trainval.set_index('time', drop=True, inplace=True)

test_result = collection[name].predict('test', unscaled=False)
test_result_unscaled = collection[name].predict('test', unscaled=True)
trade_result = source.metric.trade(test_result_unscaled, target)

# %%
print('RMSE: ', RMSE(test_result))

# %%
source.plot.plot_results({"Test": test_result}, 'BTC Price (Scaled) - ' + name, 'BTC')

# %%
source.plot.plot_results({"Train": trainval, 'Test': test_result_unscaled}, 'BTC Price (Unscaled) - ' + name, 'BTC', scale='log')

# %%
source.plot.plot_history({name: trade_result}, 'Trading Result - ' + name)

# %%
collection[name].cleanup()

# %% [markdown]
# <h5> --- Neural Net Iteration 3 [NN-3]</h5>

# %%
W = 5
target = 'price'
name = 'NN-3'

# %%
hyperparams = {'hidden_layers': 100,
               'max_iter': 10000,
               'random_state': 100}
               
collection[name] = source.neuralnet(prefix=name,
                        data=data,
                        W=W,
                        target=target,
                        hyperparams=hyperparams)

collection[name].fit()
collection[name].init_predictor()
# Out:
# 's3_input' class will be renamed to 'TrainingInput' in SageMaker Python SDK v2.
# 's3_input' class will be renamed to 'TrainingInput' in SageMaker Python SDK v2.
# 2021-02-06 14:31:48 Starting - Starting the training job...
# 2021-02-06 14:31:50 Starting - Launching requested ML instances......
# 2021-02-06 14:32:53 Starting - Preparing the instances for training...
# 2021-02-06 14:33:43 Downloading - Downloading input data...
# 2021-02-06 14:34:17 Training - Downloading the training image...
# 2021-02-06 14:34:31 Training - Training image download completed. Training in progress...2021-02-06 14:34:32,672 sagemaker-containers INFO     Imported framework sagemaker_sklearn_container.training
# 2021-02-06 14:34:32,674 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# 2021-02-06 14:34:32,684 sagemaker_sklearn_container.training INFO     Invoking user training script.
# 2021-02-06 14:34:33,093 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# 2021-02-06 14:34:33,105 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# 2021-02-06 14:34:33,117 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# 2021-02-06 14:34:33,127 sagemaker-training-toolkit INFO     Invoking user script
#
# Training Env:
#
# {
#     "additional_framework_parameters": {},
#     "channel_input_dirs": {
#         "validation": "/opt/ml/input/data/validation",
#         "train": "/opt/ml/input/data/train"
#     },
#     "current_host": "algo-1",
#     "framework_module": "sagemaker_sklearn_container.training:main",
#     "hosts": [
#         "algo-1"
#     ],
#     "hyperparameters": {
#         "max_iter": 10000,
#         "hidden_layers": 100
#     },
#     "input_config_dir": "/opt/ml/input/config",
#     "input_data_config": {
#         "validation": {
#             "TrainingInputMode": "File",
#             "S3DistributionType": "FullyReplicated",
#             "RecordWrapperType": "None"
#         },
#         "train": {
#             "TrainingInputMode": "File",
#             "S3DistributionType": "FullyReplicated",
#             "RecordWrapperType": "None"
#         }
#     },
#     "input_dir": "/opt/ml/input",
#     "is_master": true,
#     "job_name": "sagemaker-scikit-learn-2021-02-06-14-31-48-587",
#     "log_level": 20,
#     "master_hostname": "algo-1",
#     "model_dir": "/opt/ml/model",
#     "module_dir": "s3://sagemaker-us-east-2-937637726599/sagemaker-scikit-learn-2021-02-06-14-31-48-587/source/sourcedir.tar.gz",
#     "module_name": "train",
#     "network_interface_name": "eth0",
#     "num_cpus": 4,
#     "num_gpus": 0,
#     "output_data_dir": "/opt/ml/output/data",
#     "output_dir": "/opt/ml/output",
#     "output_intermediate_dir": "/opt/ml/output/intermediate",
#     "resource_config": {
#         "current_host": "algo-1",
#         "hosts": [
#             "algo-1"
#         ],
#         "network_interface_name": "eth0"
#     },
#     "user_entry_point": "train.py"
# }
#
# Environment variables:
#
# SM_HOSTS=["algo-1"]
# SM_NETWORK_INTERFACE_NAME=eth0
# SM_HPS={"hidden_layers":100,"max_iter":10000}
# SM_USER_ENTRY_POINT=train.py
# SM_FRAMEWORK_PARAMS={}
# SM_RESOURCE_CONFIG={"current_host":"algo-1","hosts":["algo-1"],"network_interface_name":"eth0"}
# SM_INPUT_DATA_CONFIG={"train":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"},"validation":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}}
# SM_OUTPUT_DATA_DIR=/opt/ml/output/data
# SM_CHANNELS=["train","validation"]
# SM_CURRENT_HOST=algo-1
# SM_MODULE_NAME=train
# SM_LOG_LEVEL=20
# SM_FRAMEWORK_MODULE=sagemaker_sklearn_container.training:main
# SM_INPUT_DIR=/opt/ml/input
# SM_INPUT_CONFIG_DIR=/opt/ml/input/config
# SM_OUTPUT_DIR=/opt/ml/output
# SM_NUM_CPUS=4
# SM_NUM_GPUS=0
# SM_MODEL_DIR=/opt/ml/model
# SM_MODULE_DIR=s3://sagemaker-us-east-2-937637726599/sagemaker-scikit-learn-2021-02-06-14-31-48-587/source/sourcedir.tar.gz
# SM_TRAINING_ENV={"additional_framework_parameters":{},"channel_input_dirs":{"train":"/opt/ml/input/data/train","validation":"/opt/ml/input/data/validation"},"current_host":"algo-1","framework_module":"sagemaker_sklearn_container.training:main","hosts":["algo-1"],"hyperparameters":{"hidden_layers":100,"max_iter":10000},"input_config_dir":"/opt/ml/input/config","input_data_config":{"train":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"},"validation":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}},"input_dir":"/opt/ml/input","is_master":true,"job_name":"sagemaker-scikit-learn-2021-02-06-14-31-48-587","log_level":20,"master_hostname":"algo-1","model_dir":"/opt/ml/model","module_dir":"s3://sagemaker-us-east-2-937637726599/sagemaker-scikit-learn-2021-02-06-14-31-48-587/source/sourcedir.tar.gz","module_name":"train","network_interface_name":"eth0","num_cpus":4,"num_gpus":0,"output_data_dir":"/opt/ml/output/data","output_dir":"/opt/ml/output","output_intermediate_dir":"/opt/ml/output/intermediate","resource_config":{"current_host":"algo-1","hosts":["algo-1"],"network_interface_name":"eth0"},"user_entry_point":"train.py"}
# SM_USER_ARGS=["--hidden_layers","100","--max_iter","10000"]
# SM_OUTPUT_INTERMEDIATE_DIR=/opt/ml/output/intermediate
# SM_CHANNEL_VALIDATION=/opt/ml/input/data/validation
# SM_CHANNEL_TRAIN=/opt/ml/input/data/train
# SM_HP_MAX_ITER=10000
# SM_HP_HIDDEN_LAYERS=100
# PYTHONPATH=/opt/ml/code:/miniconda3/bin:/miniconda3/lib/python37.zip:/miniconda3/lib/python3.7:/miniconda3/lib/python3.7/lib-dynload:/miniconda3/lib/python3.7/site-packages
#
# Invoking script with the following command:
#
# /miniconda3/bin/python train.py --hidden_layers 100 --max_iter 10000
#
#
# /miniconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:471: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# 2021-02-06 14:43:58,855 sagemaker-containers INFO     Reporting training SUCCESS
#
# 2021-02-06 14:44:49 Uploading - Uploading generated training model
# 2021-02-06 14:44:49 Completed - Training job completed
# Parameter image will be renamed to image_uri in SageMaker Python SDK v2.
# Training seconds: 666
# Billable seconds: 666
# -----------------!

# %%
trainval = collection[name].sets['trainval']['ori'].copy()
trainval.set_index('time', drop=True, inplace=True)

test_result = collection[name].predict('test', unscaled=False)
test_result_unscaled = collection[name].predict('test', unscaled=True)
trade_result = source.metric.trade(test_result_unscaled, target)

# %%
print('RMSE: ', RMSE(test_result))

# %%
source.plot.plot_results({"Test": test_result}, 'BTC Price (Scaled) - ' + name, 'BTC')

# %%
source.plot.plot_results({"Train": trainval, 'Test': test_result_unscaled}, 'BTC Price (Unscaled) - ' + name, 'BTC', scale='log')

# %%
source.plot.plot_history({name: trade_result}, 'Trading Result - ' + name)

# %%
collection[name].cleanup()

# %% [markdown]
# <h5> --- Neural Net Iteration 4 [NN-4]</h5>

# %%
W = 7
target = 'price'
name = 'NN-4'

# %%
hyperparams = {'hidden_layers': 100,
               'max_iter': 10000,
               'random_state': 100}
               
collection[name] = source.neuralnet(prefix=name,
                        data=data,
                        W=W,
                        target=target,
                        hyperparams=hyperparams)

collection[name].fit()
collection[name].init_predictor()
# Out:
# Exception ignored in: <bound method neuralnet.__del__ of <source.neuralnet.neuralnet object at 0x7f351d0986a0>>
# Traceback (most recent call last):
#   File "/home/ec2-user/SageMaker/crypto-prediction/source/neuralnet.py", line 41, in __del__
#     self.cleanup()
#   File "/home/ec2-user/SageMaker/crypto-prediction/source/neuralnet.py", line 101, in cleanup
#     self.predictor.delete_endpoint()
# AttributeError: 'NoneType' object has no attribute 'delete_endpoint'
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-6d74ed48001e> in <module>
#       7                         W=W,
#       8                         target=target,
# ----> 9                         hyperparams=hyperparams)
#      10
#      11 collection[name].fit()
#
# NameError: name 'collection' is not defined

# %%
trainval = collection[name].sets['trainval']['ori'].copy()
trainval.set_index('time', drop=True, inplace=True)

test_result = collection[name].predict('test', unscaled=False)
test_result_unscaled = collection[name].predict('test', unscaled=True)
trade_result = source.metric.trade(test_result_unscaled, target)

# %%
print('RMSE: ', RMSE(test_result))

# %%
source.plot.plot_results({"Test": test_result}, 'BTC Price (Scaled) - ' + name, 'BTC')

# %%
source.plot.plot_results({"Train": trainval, 'Test': test_result_unscaled}, 'BTC Price (Unscaled) - ' + name, 'BTC', scale='log')

# %%
source.plot.plot_history({name: trade_result}, 'Trading Result - ' + name)

# %%
collection[name].cleanup()

# %% [markdown]
# <h2> DeepAR Evaluation </h2>

# %% [markdown]
# <h5> --- DeepAR Iteration 1 [DA-1]</h5>

# %%
W = 5
target = 'price'
name = 'DA-1'

# %%
hyperparams = {
    "epochs": "500",
    "time_freq": 'D',
    "prediction_length": '1',
    "context_length": '30',
    "num_cells": "100",
    "num_layers": "4",
    "mini_batch_size": "128",
    "learning_rate": "0.1",
    "early_stopping_patience": "20"
}
               
collection[name] = source.deepar(prefix=name,
                        data=data,
                        W=W,
                        target=target,
                        hyperparams=hyperparams)

collection[name].fit()
collection[name].init_predictor()

# %%
trainval = collection[name].sets['trainval']['ori'].copy()
trainval.set_index('time', drop=True, inplace=True)

test_result = collection[name].predict('test', unscaled=False)
test_result_unscaled = collection[name].predict('test', unscaled=True)
trade_result = source.metric.trade(test_result_unscaled, target)

# %%
print('RMSE: ', RMSE(test_result))

# %%
source.plot.plot_results({"Test": test_result}, 'BTC Price (Scaled) - ' + name, 'BTC')

# %%
source.plot.plot_results({"Train": trainval, 'Test': test_result_unscaled}, 'BTC Price (Unscaled) - ' + name, 'BTC', scale='log')

# %%
source.plot.plot_history({name: trade_result}, 'Trading Result - ' + name)

# %%
collection[name].cleanup()

# %% [markdown]
# <h5> --- DeepAR Iteration 2 [DA-2]</h5>

# %%
W = 7
target = 'price'
name = 'DA-2'

# %%
hyperparams = {
    "epochs": "500",
    "time_freq": 'D',
    "prediction_length": '1',
    "context_length": '30',
    "num_cells": "100",
    "num_layers": "4",
    "mini_batch_size": "128",
    "learning_rate": "0.1",
    "early_stopping_patience": "20"
}
               
collection[name] = source.deepar(prefix=name,
                        data=data,
                        W=W,
                        target=target,
                        hyperparams=hyperparams)

collection[name].fit()
collection[name].init_predictor()

# %%
trainval = collection[name].sets['trainval']['ori'].copy()
trainval.set_index('time', drop=True, inplace=True)

test_result = collection[name].predict('test', unscaled=False)
test_result_unscaled = collection[name].predict('test', unscaled=True)
trade_result = source.metric.trade(test_result_unscaled, target)

# %%
print('RMSE: ', RMSE(test_result))

# %%
source.plot.plot_results({"Test": test_result}, 'BTC Price (Scaled) - ' + name, 'BTC')

# %%
source.plot.plot_results({"Train": trainval, 'Test': test_result_unscaled}, 'BTC Price (Unscaled) - ' + name, 'BTC', scale='log')

# %%
source.plot.plot_history({name: trade_result}, 'Trading Result - ' + name)

# %%
collection[name].cleanup()

# %% [markdown]
# <h5> --- DeepAR Iteration 3 [DA-3]</h5>

# %%
W = 5
target = 'price'
name = 'DA-3'

# %%
hyperparams = {
    "epochs": "500",
    "time_freq": 'D',
    "prediction_length": '1',
    "context_length": '30',
    "num_cells": "200",
    "num_layers": "4",
    "mini_batch_size": "128",
    "learning_rate": "0.1",
    "early_stopping_patience": "20"
}
               
collection[name] = source.deepar(prefix=name,
                        data=data,
                        W=W,
                        target=target,
                        hyperparams=hyperparams)

collection[name].fit()
collection[name].init_predictor()

# %%
trainval = collection[name].sets['trainval']['ori'].copy()
trainval.set_index('time', drop=True, inplace=True)

test_result = collection[name].predict('test', unscaled=False)
test_result_unscaled = collection[name].predict('test', unscaled=True)
trade_result = source.metric.trade(test_result_unscaled, target)

# %%
print('RMSE: ', RMSE(test_result))

# %%
source.plot.plot_results({"Test": test_result}, 'BTC Price (Scaled) - ' + name, 'BTC')

# %%
source.plot.plot_results({"Train": trainval, 'Test': test_result_unscaled}, 'BTC Price (Unscaled) - ' + name, 'BTC', scale='log')

# %%
source.plot.plot_history({name: trade_result}, 'Trading Result - ' + name)

# %%
collection[name].cleanup()

# %% [markdown]
# <h5> --- DeepAR Iteration 4 [DA-4]</h5>

# %%
W = 7
target = 'price'
name = 'DA-4'

# %%
hyperparams = {
    "epochs": "500",
    "time_freq": 'D',
    "prediction_length": '1',
    "context_length": '30',
    "num_cells": "200",
    "num_layers": "4",
    "mini_batch_size": "128",
    "learning_rate": "0.1",
    "early_stopping_patience": "20"
}
               
collection[name] = source.deepar(prefix=name,
                        data=data,
                        W=W,
                        target=target,
                        hyperparams=hyperparams)

collection[name].fit()
collection[name].init_predictor()

# %%
trainval = collection[name].sets['trainval']['ori'].copy()
trainval.set_index('time', drop=True, inplace=True)

test_result = collection[name].predict('test', unscaled=False)
test_result_unscaled = collection[name].predict('test', unscaled=True)
trade_result = source.metric.trade(test_result_unscaled, target)

# %%
print('RMSE: ', RMSE(test_result))

# %%
source.plot.plot_results({"Test": test_result}, 'BTC Price (Scaled) - ' + name, 'BTC')

# %%
source.plot.plot_results({"Train": trainval, 'Test': test_result_unscaled}, 'BTC Price (Unscaled) - ' + name, 'BTC', scale='log')

# %%
source.plot.plot_history({name: trade_result}, 'Trading Result - ' + name)

# %%
collection[name].cleanup()

# %% [markdown]
# <h2> XGBoost Optimization </h2>

# %%
from sagemaker.tuner import IntegerParameter, ContinuousParameter

# %%
W = 7
target = 'price'
name = 'XGB-Optim'

# %%
hyperparams = {'max_depth':20,
               'eta':0.1,
               'gamma':0.2,
               'min_child_weight':15,
               'subsample':0.8,
               'objective':'reg:linear',
               'early_stopping_rounds':20,
               'num_round':300,
               'seed':100}

xgb_optim = source.xgboost(prefix=name,
                           data=data,
                           W=W,
                           target=target,
                           hyperparams=hyperparams)

# %%
hyperparameter_ranges = {'max_depth': IntegerParameter(5, 20),
                         'eta'      : ContinuousParameter(0.05, 0.5),
                         'min_child_weight': IntegerParameter(2, 20),
                         'subsample': ContinuousParameter(0.5, 0.9),
                         'gamma': ContinuousParameter(0,4)}

tuner = xgb_optim.tuned_fit(hyperparameter_ranges)
# Out:
# 's3_input' class will be renamed to 'TrainingInput' in SageMaker Python SDK v2.
# 's3_input' class will be renamed to 'TrainingInput' in SageMaker Python SDK v2.
# 'get_image_uri' method will be deprecated in favor of 'ImageURIProvider' class in SageMaker Python SDK v2.
# There is a more up to date SageMaker XGBoost image. To use the newer image, please set 'repo_version'='1.0-1'. For example:
# 	get_image_uri(region, 'xgboost', '1.0-1').
# Parameter image_name will be renamed to image_uri in SageMaker Python SDK v2.
# ...................................................................................................................................................................................................................................................!
# Parameter image_name will be renamed to image_uri in SageMaker Python SDK v2.
# 2021-02-06 16:37:00 Starting - Preparing the instances for training
# 2021-02-06 16:37:00 Downloading - Downloading input data
# 2021-02-06 16:37:00 Training - Training image download completed. Training in progress.
# 2021-02-06 16:37:00 Uploading - Uploading generated training model
# 2021-02-06 16:37:00 Completed - Training job completedArguments: train
# [2021-02-06:16:35:57:INFO] Running standalone xgboost training.
# [2021-02-06:16:35:57:INFO] Setting up HPO optimized metric to be : rmse
# [2021-02-06:16:35:57:INFO] File size need to be processed in the node: 35.11mb. Available memory size in the node: 8424.7mb
# [2021-02-06:16:35:57:INFO] Determined delimiter of CSV input is ','
# [16:35:57] S3DistributionType set as FullyReplicated
# [16:35:57] 25788x49 matrix with 1263612 entries loaded from /opt/ml/input/data/train?format=csv&label_column=0&delimiter=,
# [2021-02-06:16:35:57:INFO] Determined delimiter of CSV input is ','
# [16:35:57] S3DistributionType set as FullyReplicated
# [16:35:57] 13847x49 matrix with 678503 entries loaded from /opt/ml/input/data/validation?format=csv&label_column=0&delimiter=,
# [16:35:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 776 extra nodes, 2018 pruned nodes, max_depth=15
# [0]#011train-rmse:2.07362#011validation-rmse:2.28096
# Multiple eval metrics have been passed: 'validation-rmse' will be used for early stopping.
#
# Will train until validation-rmse hasn't improved in 20 rounds.
# [16:35:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 746 extra nodes, 2094 pruned nodes, max_depth=15
# [1]#011train-rmse:1.97971#011validation-rmse:2.20711
# [16:35:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 734 extra nodes, 2080 pruned nodes, max_depth=16
# [2]#011train-rmse:1.89213#011validation-rmse:2.13626
# [16:35:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 732 extra nodes, 2176 pruned nodes, max_depth=15
# [3]#011train-rmse:1.80873#011validation-rmse:2.07191
# [16:35:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 730 extra nodes, 2280 pruned nodes, max_depth=17
# [4]#011train-rmse:1.73204#011validation-rmse:2.01152
# [16:35:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 714 extra nodes, 2398 pruned nodes, max_depth=17
# [5]#011train-rmse:1.6552#011validation-rmse:1.95135
# [16:35:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 678 extra nodes, 2448 pruned nodes, max_depth=16
# [6]#011train-rmse:1.58627#011validation-rmse:1.89858
# [16:35:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 652 extra nodes, 2542 pruned nodes, max_depth=16
# [7]#011train-rmse:1.51947#011validation-rmse:1.85053
# [16:35:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 658 extra nodes, 2608 pruned nodes, max_depth=16
# [8]#011train-rmse:1.45675#011validation-rmse:1.80815
# [16:35:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 614 extra nodes, 2728 pruned nodes, max_depth=14
# [9]#011train-rmse:1.39648#011validation-rmse:1.76617
# [16:36:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 598 extra nodes, 2698 pruned nodes, max_depth=15
# [10]#011train-rmse:1.34232#011validation-rmse:1.72834
# [16:36:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 580 extra nodes, 2790 pruned nodes, max_depth=15
# [11]#011train-rmse:1.29118#011validation-rmse:1.69234
# [16:36:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 584 extra nodes, 2852 pruned nodes, max_depth=17
# [12]#011train-rmse:1.23659#011validation-rmse:1.64501
# [16:36:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 566 extra nodes, 3036 pruned nodes, max_depth=15
# [13]#011train-rmse:1.18844#011validation-rmse:1.61428
# [16:36:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 562 extra nodes, 3066 pruned nodes, max_depth=17
# [14]#011train-rmse:1.14422#011validation-rmse:1.58397
# [16:36:01] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 532 extra nodes, 3120 pruned nodes, max_depth=17
# [15]#011train-rmse:1.09615#011validation-rmse:1.54828
# [16:36:01] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 542 extra nodes, 3254 pruned nodes, max_depth=15
# [16]#011train-rmse:1.05407#011validation-rmse:1.52442
# [16:36:01] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 542 extra nodes, 3210 pruned nodes, max_depth=15
# [17]#011train-rmse:1.015#011validation-rmse:1.50247
# [16:36:01] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 516 extra nodes, 3474 pruned nodes, max_depth=13
# [18]#011train-rmse:0.974728#011validation-rmse:1.47227
# [16:36:02] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 500 extra nodes, 3516 pruned nodes, max_depth=15
# [19]#011train-rmse:0.93938#011validation-rmse:1.45123
# [16:36:02] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 478 extra nodes, 3570 pruned nodes, max_depth=14
# [20]#011train-rmse:0.904472#011validation-rmse:1.42355
# [16:36:02] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 456 extra nodes, 3516 pruned nodes, max_depth=15
# [21]#011train-rmse:0.872781#011validation-rmse:1.40714
# [16:36:03] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 492 extra nodes, 3476 pruned nodes, max_depth=18
# [22]#011train-rmse:0.839205#011validation-rmse:1.39126
# [16:36:03] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 450 extra nodes, 3818 pruned nodes, max_depth=14
# [23]#011train-rmse:0.809924#011validation-rmse:1.37728
# [16:36:03] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 432 extra nodes, 3868 pruned nodes, max_depth=14
# [24]#011train-rmse:0.784325#011validation-rmse:1.36305
# [16:36:03] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 420 extra nodes, 4020 pruned nodes, max_depth=14
# [25]#011train-rmse:0.762532#011validation-rmse:1.35127
# [16:36:04] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 420 extra nodes, 4152 pruned nodes, max_depth=16
# [26]#011train-rmse:0.733497#011validation-rmse:1.34197
# [16:36:04] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 374 extra nodes, 4184 pruned nodes, max_depth=13
# [27]#011train-rmse:0.710361#011validation-rmse:1.33061
# [16:36:04] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 394 extra nodes, 4344 pruned nodes, max_depth=14
# [28]#011train-rmse:0.688898#011validation-rmse:1.32072
# [16:36:05] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 376 extra nodes, 4034 pruned nodes, max_depth=15
# [29]#011train-rmse:0.670189#011validation-rmse:1.31239
# [16:36:05] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 362 extra nodes, 4458 pruned nodes, max_depth=16
# [30]#011train-rmse:0.652601#011validation-rmse:1.30538
# [16:36:05] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 388 extra nodes, 4042 pruned nodes, max_depth=16
# [31]#011train-rmse:0.629929#011validation-rmse:1.28727
# [16:36:06] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 326 extra nodes, 4062 pruned nodes, max_depth=15
# [32]#011train-rmse:0.609666#011validation-rmse:1.27662
# [16:36:06] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 320 extra nodes, 4308 pruned nodes, max_depth=17
# [33]#011train-rmse:0.589052#011validation-rmse:1.2603
# [16:36:06] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 338 extra nodes, 4380 pruned nodes, max_depth=12
# [34]#011train-rmse:0.569582#011validation-rmse:1.25426
# [16:36:07] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 322 extra nodes, 4508 pruned nodes, max_depth=15
# [35]#011train-rmse:0.554666#011validation-rmse:1.25002
# [16:36:07] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 290 extra nodes, 4116 pruned nodes, max_depth=15
# [36]#011train-rmse:0.539568#011validation-rmse:1.24331
# [16:36:07] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 288 extra nodes, 4684 pruned nodes, max_depth=14
# [37]#011train-rmse:0.525557#011validation-rmse:1.23064
# [16:36:07] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 278 extra nodes, 4580 pruned nodes, max_depth=14
# [38]#011train-rmse:0.512208#011validation-rmse:1.22691
# [16:36:08] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 280 extra nodes, 4360 pruned nodes, max_depth=14
# [39]#011train-rmse:0.499432#011validation-rmse:1.22238
# [16:36:08] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 278 extra nodes, 4258 pruned nodes, max_depth=13
# [40]#011train-rmse:0.486555#011validation-rmse:1.21867
# [16:36:08] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 254 extra nodes, 4536 pruned nodes, max_depth=13
# [41]#011train-rmse:0.476206#011validation-rmse:1.21542
# [16:36:08] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 260 extra nodes, 4404 pruned nodes, max_depth=16
# [42]#011train-rmse:0.465405#011validation-rmse:1.2131
# [16:36:08] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 292 extra nodes, 4188 pruned nodes, max_depth=18
# [43]#011train-rmse:0.45071#011validation-rmse:1.20224
# [16:36:09] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 236 extra nodes, 4452 pruned nodes, max_depth=15
# [44]#011train-rmse:0.440795#011validation-rmse:1.19936
# [16:36:09] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 216 extra nodes, 4842 pruned nodes, max_depth=13
# [45]#011train-rmse:0.433201#011validation-rmse:1.19676
# [16:36:09] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 218 extra nodes, 4426 pruned nodes, max_depth=13
# [46]#011train-rmse:0.422019#011validation-rmse:1.1924
# [16:36:09] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 236 extra nodes, 4186 pruned nodes, max_depth=16
# [47]#011train-rmse:0.411739#011validation-rmse:1.18778
# [16:36:10] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 222 extra nodes, 4488 pruned nodes, max_depth=18
# [48]#011train-rmse:0.403129#011validation-rmse:1.18788
# [16:36:10] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 228 extra nodes, 4462 pruned nodes, max_depth=15
# [49]#011train-rmse:0.39372#011validation-rmse:1.18635
# [16:36:10] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 224 extra nodes, 3974 pruned nodes, max_depth=18
# [50]#011train-rmse:0.382885#011validation-rmse:1.18112
# [16:36:10] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 180 extra nodes, 4398 pruned nodes, max_depth=13
# [51]#011train-rmse:0.375268#011validation-rmse:1.17817
# [16:36:11] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 170 extra nodes, 4480 pruned nodes, max_depth=16
# [52]#011train-rmse:0.370939#011validation-rmse:1.1764
# [16:36:11] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 156 extra nodes, 5312 pruned nodes, max_depth=13
# [53]#011train-rmse:0.366229#011validation-rmse:1.17363
# [16:36:11] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 198 extra nodes, 4456 pruned nodes, max_depth=16
# [54]#011train-rmse:0.360759#011validation-rmse:1.17102
# [16:36:11] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 202 extra nodes, 4086 pruned nodes, max_depth=18
# [55]#011train-rmse:0.35184#011validation-rmse:1.16927
# [16:36:12] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 152 extra nodes, 4486 pruned nodes, max_depth=14
# [56]#011train-rmse:0.345498#011validation-rmse:1.16418
# [16:36:12] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 198 extra nodes, 4076 pruned nodes, max_depth=16
# [57]#011train-rmse:0.337343#011validation-rmse:1.16173
# [16:36:12] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 178 extra nodes, 3974 pruned nodes, max_depth=17
# [58]#011train-rmse:0.329423#011validation-rmse:1.15998
# [16:36:12] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 156 extra nodes, 3942 pruned nodes, max_depth=17
# [59]#011train-rmse:0.323092#011validation-rmse:1.15433
# [16:36:13] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 154 extra nodes, 4358 pruned nodes, max_depth=15
# [60]#011train-rmse:0.318054#011validation-rmse:1.15263
# [16:36:13] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 154 extra nodes, 4164 pruned nodes, max_depth=13
# [61]#011train-rmse:0.313731#011validation-rmse:1.15003
# [16:36:13] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 142 extra nodes, 3930 pruned nodes, max_depth=17
# [62]#011train-rmse:0.307445#011validation-rmse:1.14683
# [16:36:13] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 132 extra nodes, 4306 pruned nodes, max_depth=18
# [63]#011train-rmse:0.302961#011validation-rmse:1.14448
# [16:36:13] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 132 extra nodes, 4368 pruned nodes, max_depth=13
# [64]#011train-rmse:0.299024#011validation-rmse:1.14337
# [16:36:14] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 104 extra nodes, 3494 pruned nodes, max_depth=13
# [65]#011train-rmse:0.293499#011validation-rmse:1.14201
# [16:36:14] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 172 extra nodes, 3820 pruned nodes, max_depth=18
# [66]#011train-rmse:0.287519#011validation-rmse:1.14047
# [16:36:14] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 128 extra nodes, 4394 pruned nodes, max_depth=12
# [67]#011train-rmse:0.284151#011validation-rmse:1.14002
# [16:36:14] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 134 extra nodes, 3462 pruned nodes, max_depth=17
# [68]#011train-rmse:0.278527#011validation-rmse:1.14014
# [16:36:15] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 112 extra nodes, 3606 pruned nodes, max_depth=14
# [69]#011train-rmse:0.27448#011validation-rmse:1.13783
# [16:36:15] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 136 extra nodes, 3192 pruned nodes, max_depth=18
# [70]#011train-rmse:0.270927#011validation-rmse:1.13744
# [16:36:15] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 120 extra nodes, 2818 pruned nodes, max_depth=18
# [71]#011train-rmse:0.266605#011validation-rmse:1.13568
# [16:36:15] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 110 extra nodes, 3730 pruned nodes, max_depth=11
# [72]#011train-rmse:0.262684#011validation-rmse:1.13098
# [16:36:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 120 extra nodes, 3902 pruned nodes, max_depth=17
# [73]#011train-rmse:0.260113#011validation-rmse:1.13124
# [16:36:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 122 extra nodes, 4598 pruned nodes, max_depth=12
# [74]#011train-rmse:0.255857#011validation-rmse:1.13078
# [16:36:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 102 extra nodes, 2994 pruned nodes, max_depth=12
# [75]#011train-rmse:0.253851#011validation-rmse:1.13029
# [16:36:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 100 extra nodes, 3386 pruned nodes, max_depth=13
# [76]#011train-rmse:0.249921#011validation-rmse:1.12881
# [16:36:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 76 extra nodes, 3466 pruned nodes, max_depth=11
# [77]#011train-rmse:0.24678#011validation-rmse:1.12728
# [16:36:17] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 74 extra nodes, 2720 pruned nodes, max_depth=17
# [78]#011train-rmse:0.243657#011validation-rmse:1.12615
# [16:36:17] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 94 extra nodes, 4496 pruned nodes, max_depth=11
# [79]#011train-rmse:0.241697#011validation-rmse:1.12532
# [16:36:17] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 82 extra nodes, 2958 pruned nodes, max_depth=11
# [80]#011train-rmse:0.239266#011validation-rmse:1.12471
# [16:36:17] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 64 extra nodes, 3218 pruned nodes, max_depth=10
# [81]#011train-rmse:0.236548#011validation-rmse:1.12461
# [16:36:18] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 96 extra nodes, 3454 pruned nodes, max_depth=17
# [82]#011train-rmse:0.233852#011validation-rmse:1.12329
# [16:36:18] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 106 extra nodes, 3990 pruned nodes, max_depth=14
# [83]#011train-rmse:0.232208#011validation-rmse:1.12298
# [16:36:18] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 72 extra nodes, 2546 pruned nodes, max_depth=16
# [84]#011train-rmse:0.230157#011validation-rmse:1.12253
# [16:36:18] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 98 extra nodes, 2378 pruned nodes, max_depth=18
# [85]#011train-rmse:0.228427#011validation-rmse:1.12263
# [16:36:19] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 74 extra nodes, 3168 pruned nodes, max_depth=17
# [86]#011train-rmse:0.226112#011validation-rmse:1.12166
# [16:36:19] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 74 extra nodes, 1706 pruned nodes, max_depth=13
# [87]#011train-rmse:0.223353#011validation-rmse:1.12177
# [16:36:19] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 72 extra nodes, 2078 pruned nodes, max_depth=17
# [88]#011train-rmse:0.222304#011validation-rmse:1.12146
# [16:36:19] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 90 extra nodes, 1442 pruned nodes, max_depth=18
# [89]#011train-rmse:0.220913#011validation-rmse:1.12036
# [16:36:19] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 78 extra nodes, 2770 pruned nodes, max_depth=14
# [90]#011train-rmse:0.218679#011validation-rmse:1.12061
# [16:36:20] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 76 extra nodes, 2138 pruned nodes, max_depth=15
# [91]#011train-rmse:0.217535#011validation-rmse:1.12043
# [16:36:20] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 64 extra nodes, 2512 pruned nodes, max_depth=11
# [92]#011train-rmse:0.215284#011validation-rmse:1.11982
# [16:36:20] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 94 extra nodes, 3782 pruned nodes, max_depth=16
# [93]#011train-rmse:0.213951#011validation-rmse:1.11938
# [16:36:20] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 54 extra nodes, 2350 pruned nodes, max_depth=12
# [94]#011train-rmse:0.212151#011validation-rmse:1.11912
# [16:36:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 80 extra nodes, 1288 pruned nodes, max_depth=18
# [95]#011train-rmse:0.210301#011validation-rmse:1.11933
# [16:36:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 60 extra nodes, 2418 pruned nodes, max_depth=12
# [96]#011train-rmse:0.208603#011validation-rmse:1.11979
# [16:36:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 54 extra nodes, 2542 pruned nodes, max_depth=14
# [97]#011train-rmse:0.206821#011validation-rmse:1.1194
# [16:36:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 82 extra nodes, 2922 pruned nodes, max_depth=15
# [98]#011train-rmse:0.205528#011validation-rmse:1.11835
# [16:36:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 84 extra nodes, 2104 pruned nodes, max_depth=17
# [99]#011train-rmse:0.204272#011validation-rmse:1.1177
# [16:36:22] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 66 extra nodes, 2444 pruned nodes, max_depth=14
# [100]#011train-rmse:0.202679#011validation-rmse:1.11798
# [16:36:22] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 3348 pruned nodes, max_depth=8
# [101]#011train-rmse:0.202301#011validation-rmse:1.11748
# [16:36:22] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 82 extra nodes, 2856 pruned nodes, max_depth=16
# [102]#011train-rmse:0.201268#011validation-rmse:1.11678
# [16:36:22] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 56 extra nodes, 2944 pruned nodes, max_depth=14
# [103]#011train-rmse:0.199895#011validation-rmse:1.11634
# [16:36:23] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 68 extra nodes, 2952 pruned nodes, max_depth=16
# [104]#011train-rmse:0.198457#011validation-rmse:1.11644
# [16:36:23] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 38 extra nodes, 1982 pruned nodes, max_depth=10
# [105]#011train-rmse:0.197451#011validation-rmse:1.11656
# [16:36:23] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 52 extra nodes, 1828 pruned nodes, max_depth=15
# [106]#011train-rmse:0.196952#011validation-rmse:1.11659
# [16:36:23] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 50 extra nodes, 680 pruned nodes, max_depth=18
# [107]#011train-rmse:0.195777#011validation-rmse:1.11551
# [16:36:23] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 48 extra nodes, 674 pruned nodes, max_depth=11
# [108]#011train-rmse:0.194502#011validation-rmse:1.1152
# [16:36:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 36 extra nodes, 440 pruned nodes, max_depth=10
# [109]#011train-rmse:0.193261#011validation-rmse:1.11508
# [16:36:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 46 extra nodes, 3558 pruned nodes, max_depth=11
# [110]#011train-rmse:0.19234#011validation-rmse:1.11475
# [16:36:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 62 extra nodes, 1646 pruned nodes, max_depth=14
# [111]#011train-rmse:0.191294#011validation-rmse:1.11391
# [16:36:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 1442 pruned nodes, max_depth=6
# [112]#011train-rmse:0.19064#011validation-rmse:1.11238
# [16:36:25] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 44 extra nodes, 2230 pruned nodes, max_depth=12
# [113]#011train-rmse:0.18972#011validation-rmse:1.11231
# [16:36:25] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 62 extra nodes, 2156 pruned nodes, max_depth=13
# [114]#011train-rmse:0.189282#011validation-rmse:1.11243
# [16:36:25] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 1474 pruned nodes, max_depth=8
# [115]#011train-rmse:0.188904#011validation-rmse:1.11219
# [16:36:25] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 50 extra nodes, 1160 pruned nodes, max_depth=16
# [116]#011train-rmse:0.187915#011validation-rmse:1.11186
# [16:36:25] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 44 extra nodes, 1500 pruned nodes, max_depth=10
# [117]#011train-rmse:0.187398#011validation-rmse:1.11122
# [16:36:26] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 58 extra nodes, 1354 pruned nodes, max_depth=14
# [118]#011train-rmse:0.186561#011validation-rmse:1.11067
# [16:36:26] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 46 extra nodes, 1446 pruned nodes, max_depth=14
# [119]#011train-rmse:0.185758#011validation-rmse:1.11073
# [16:36:26] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 62 extra nodes, 1608 pruned nodes, max_depth=15
# [120]#011train-rmse:0.185064#011validation-rmse:1.11011
# [16:36:26] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 40 extra nodes, 1168 pruned nodes, max_depth=16
# [121]#011train-rmse:0.184739#011validation-rmse:1.11046
# [16:36:26] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 70 extra nodes, 2556 pruned nodes, max_depth=18
# [122]#011train-rmse:0.183895#011validation-rmse:1.10992
# [16:36:27] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 44 extra nodes, 816 pruned nodes, max_depth=15
# [123]#011train-rmse:0.183017#011validation-rmse:1.11029
# [16:36:27] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 78 extra nodes, 1306 pruned nodes, max_depth=18
# [124]#011train-rmse:0.181976#011validation-rmse:1.1094
# [16:36:27] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 42 extra nodes, 1122 pruned nodes, max_depth=13
# [125]#011train-rmse:0.181547#011validation-rmse:1.10943
# [16:36:27] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 38 extra nodes, 2630 pruned nodes, max_depth=13
# [126]#011train-rmse:0.180823#011validation-rmse:1.10936
# [16:36:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 50 extra nodes, 2464 pruned nodes, max_depth=12
# [127]#011train-rmse:0.180176#011validation-rmse:1.10901
# [16:36:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 60 extra nodes, 1300 pruned nodes, max_depth=17
# [128]#011train-rmse:0.179855#011validation-rmse:1.10865
# [16:36:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 48 extra nodes, 1012 pruned nodes, max_depth=15
# [129]#011train-rmse:0.179199#011validation-rmse:1.10942
# [16:36:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 1402 pruned nodes, max_depth=13
# [130]#011train-rmse:0.178758#011validation-rmse:1.10997
# [16:36:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 58 extra nodes, 3158 pruned nodes, max_depth=14
# [131]#011train-rmse:0.178324#011validation-rmse:1.11029
# [16:36:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 36 extra nodes, 446 pruned nodes, max_depth=15
# [132]#011train-rmse:0.177944#011validation-rmse:1.10997
# [16:36:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 40 extra nodes, 840 pruned nodes, max_depth=16
# [133]#011train-rmse:0.177432#011validation-rmse:1.10916
# [16:36:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 516 pruned nodes, max_depth=8
# [134]#011train-rmse:0.177099#011validation-rmse:1.10888
# [16:36:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 40 extra nodes, 770 pruned nodes, max_depth=17
# [135]#011train-rmse:0.176802#011validation-rmse:1.10846
# [16:36:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 34 extra nodes, 1806 pruned nodes, max_depth=10
# [136]#011train-rmse:0.176275#011validation-rmse:1.1081
# [16:36:30] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 64 extra nodes, 662 pruned nodes, max_depth=17
# [137]#011train-rmse:0.175831#011validation-rmse:1.10798
# [16:36:30] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 38 extra nodes, 90 pruned nodes, max_depth=18
# [138]#011train-rmse:0.17559#011validation-rmse:1.10819
# [16:36:30] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 36 extra nodes, 434 pruned nodes, max_depth=15
# [139]#011train-rmse:0.175421#011validation-rmse:1.10798
# [16:36:30] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 1254 pruned nodes, max_depth=8
# [140]#011train-rmse:0.175361#011validation-rmse:1.1082
# [16:36:30] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 1524 pruned nodes, max_depth=8
# [141]#011train-rmse:0.175304#011validation-rmse:1.10818
# [16:36:31] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 26 extra nodes, 2604 pruned nodes, max_depth=10
# [142]#011train-rmse:0.174958#011validation-rmse:1.10813
# [16:36:31] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 590 pruned nodes, max_depth=9
# [143]#011train-rmse:0.174616#011validation-rmse:1.10811
# [16:36:31] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 42 extra nodes, 230 pruned nodes, max_depth=18
# [144]#011train-rmse:0.174221#011validation-rmse:1.10844
# [16:36:31] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 52 extra nodes, 690 pruned nodes, max_depth=16
# [145]#011train-rmse:0.173802#011validation-rmse:1.10821
# [16:36:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 34 extra nodes, 514 pruned nodes, max_depth=13
# [146]#011train-rmse:0.173461#011validation-rmse:1.10853
# [16:36:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 32 extra nodes, 634 pruned nodes, max_depth=13
# [147]#011train-rmse:0.173181#011validation-rmse:1.10835
# [16:36:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 56 extra nodes, 806 pruned nodes, max_depth=18
# [148]#011train-rmse:0.172834#011validation-rmse:1.10829
# [16:36:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 44 extra nodes, 638 pruned nodes, max_depth=16
# [149]#011train-rmse:0.172569#011validation-rmse:1.10809
# [16:36:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 1482 pruned nodes, max_depth=3
# [150]#011train-rmse:0.172516#011validation-rmse:1.10802
# [16:36:33] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 34 extra nodes, 1208 pruned nodes, max_depth=12
# [151]#011train-rmse:0.17232#011validation-rmse:1.10809
# [16:36:33] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 46 extra nodes, 650 pruned nodes, max_depth=16
# [152]#011train-rmse:0.171955#011validation-rmse:1.10792
# [16:36:33] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 38 extra nodes, 568 pruned nodes, max_depth=18
# [153]#011train-rmse:0.171621#011validation-rmse:1.10807
# [16:36:33] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 34 extra nodes, 746 pruned nodes, max_depth=13
# [154]#011train-rmse:0.171279#011validation-rmse:1.10857
# [16:36:33] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 488 pruned nodes, max_depth=12
# [155]#011train-rmse:0.171014#011validation-rmse:1.10872
# [16:36:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 36 extra nodes, 976 pruned nodes, max_depth=16
# [156]#011train-rmse:0.17079#011validation-rmse:1.10869
# [16:36:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 42 extra nodes, 506 pruned nodes, max_depth=17
# [157]#011train-rmse:0.170675#011validation-rmse:1.10861
# [16:36:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 1452 pruned nodes, max_depth=5
# [158]#011train-rmse:0.170462#011validation-rmse:1.10833
# [16:36:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 1406 pruned nodes, max_depth=9
# [159]#011train-rmse:0.170354#011validation-rmse:1.10844
# [16:36:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 1574 pruned nodes, max_depth=5
# [160]#011train-rmse:0.17018#011validation-rmse:1.10861
# [16:36:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 382 pruned nodes, max_depth=2
# [161]#011train-rmse:0.170124#011validation-rmse:1.10855
# [16:36:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 40 extra nodes, 546 pruned nodes, max_depth=18
# [162]#011train-rmse:0.169941#011validation-rmse:1.10857
# [16:36:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 242 pruned nodes, max_depth=9
# [163]#011train-rmse:0.169646#011validation-rmse:1.10862
# [16:36:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 42 extra nodes, 840 pruned nodes, max_depth=17
# [164]#011train-rmse:0.169317#011validation-rmse:1.10863
# [16:36:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 472 pruned nodes, max_depth=2
# [165]#011train-rmse:0.169353#011validation-rmse:1.10875
# [16:36:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 246 pruned nodes, max_depth=5
# [166]#011train-rmse:0.169203#011validation-rmse:1.10885
# [16:36:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 34 extra nodes, 658 pruned nodes, max_depth=14
# [167]#011train-rmse:0.168968#011validation-rmse:1.10903
# [16:36:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 734 pruned nodes, max_depth=2
# [168]#011train-rmse:0.168811#011validation-rmse:1.10912
# [16:36:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 36 extra nodes, 688 pruned nodes, max_depth=16
# [169]#011train-rmse:0.168582#011validation-rmse:1.10882
# [16:36:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 34 extra nodes, 442 pruned nodes, max_depth=14
# [170]#011train-rmse:0.168295#011validation-rmse:1.10812
# [16:36:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 1642 pruned nodes, max_depth=2
# [171]#011train-rmse:0.168191#011validation-rmse:1.10827
# [16:36:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 572 pruned nodes, max_depth=13
# [172]#011train-rmse:0.168064#011validation-rmse:1.10781
# [16:36:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 46 extra nodes, 588 pruned nodes, max_depth=17
# [173]#011train-rmse:0.167798#011validation-rmse:1.1078
# [16:36:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 396 pruned nodes, max_depth=3
# [174]#011train-rmse:0.167752#011validation-rmse:1.10786
# [16:36:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 730 pruned nodes, max_depth=11
# [175]#011train-rmse:0.167606#011validation-rmse:1.10798
# [16:36:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 32 extra nodes, 1238 pruned nodes, max_depth=10
# [176]#011train-rmse:0.167322#011validation-rmse:1.10777
# [16:36:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 34 extra nodes, 704 pruned nodes, max_depth=16
# [177]#011train-rmse:0.167126#011validation-rmse:1.10767
# [16:36:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 728 pruned nodes, max_depth=14
# [178]#011train-rmse:0.167063#011validation-rmse:1.10767
# [16:36:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 466 pruned nodes, max_depth=5
# [179]#011train-rmse:0.166908#011validation-rmse:1.10786
# [16:36:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 688 pruned nodes, max_depth=4
# [180]#011train-rmse:0.16672#011validation-rmse:1.10775
# [16:36:39] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 360 pruned nodes, max_depth=2
# [181]#011train-rmse:0.166724#011validation-rmse:1.1079
# [16:36:39] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 2582 pruned nodes, max_depth=8
# [182]#011train-rmse:0.166609#011validation-rmse:1.10786
# [16:36:39] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 204 pruned nodes, max_depth=5
# [183]#011train-rmse:0.166535#011validation-rmse:1.10785
# [16:36:39] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 1192 pruned nodes, max_depth=2
# [184]#011train-rmse:0.166492#011validation-rmse:1.10773
# [16:36:39] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 624 pruned nodes, max_depth=10
# [185]#011train-rmse:0.166393#011validation-rmse:1.10706
# [16:36:40] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 40 extra nodes, 1608 pruned nodes, max_depth=16
# [186]#011train-rmse:0.166214#011validation-rmse:1.10714
# [16:36:40] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 226 pruned nodes, max_depth=3
# [187]#011train-rmse:0.166174#011validation-rmse:1.10731
# [16:36:40] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 554 pruned nodes, max_depth=0
# [188]#011train-rmse:0.166174#011validation-rmse:1.10731
# [16:36:40] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 362 pruned nodes, max_depth=0
# [189]#011train-rmse:0.166174#011validation-rmse:1.10731
# [16:36:40] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 1514 pruned nodes, max_depth=0
# [190]#011train-rmse:0.166174#011validation-rmse:1.10731
# [16:36:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 856 pruned nodes, max_depth=0
# [191]#011train-rmse:0.166174#011validation-rmse:1.10731
# [16:36:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 194 pruned nodes, max_depth=2
# [192]#011train-rmse:0.166103#011validation-rmse:1.10646
# [16:36:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 194 pruned nodes, max_depth=2
# [193]#011train-rmse:0.166066#011validation-rmse:1.10642
# [16:36:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 542 pruned nodes, max_depth=6
# [194]#011train-rmse:0.166013#011validation-rmse:1.10659
# [16:36:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 196 pruned nodes, max_depth=2
# [195]#011train-rmse:0.166014#011validation-rmse:1.10671
# [16:36:42] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 506 pruned nodes, max_depth=5
# [196]#011train-rmse:0.165953#011validation-rmse:1.10668
# [16:36:42] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 1742 pruned nodes, max_depth=9
# [197]#011train-rmse:0.165772#011validation-rmse:1.10649
# [16:36:42] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 32 extra nodes, 2114 pruned nodes, max_depth=12
# [198]#011train-rmse:0.165562#011validation-rmse:1.10669
# [16:36:42] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 4814 pruned nodes, max_depth=5
# [199]#011train-rmse:0.165422#011validation-rmse:1.10669
# [16:36:43] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 1030 pruned nodes, max_depth=6
# [200]#011train-rmse:0.165352#011validation-rmse:1.10672
# [16:36:43] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 962 pruned nodes, max_depth=2
# [201]#011train-rmse:0.165349#011validation-rmse:1.10686
# [16:36:43] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 1072 pruned nodes, max_depth=8
# [202]#011train-rmse:0.165221#011validation-rmse:1.10701
# [16:36:43] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 1102 pruned nodes, max_depth=5
# [203]#011train-rmse:0.165076#011validation-rmse:1.10713
# [16:36:43] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 520 pruned nodes, max_depth=5
# [204]#011train-rmse:0.164986#011validation-rmse:1.1071
# [16:36:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 1272 pruned nodes, max_depth=9
# [205]#011train-rmse:0.16485#011validation-rmse:1.10685
# [16:36:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 742 pruned nodes, max_depth=9
# [206]#011train-rmse:0.164794#011validation-rmse:1.1066
# [16:36:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 492 pruned nodes, max_depth=4
# [207]#011train-rmse:0.164753#011validation-rmse:1.1066
# [16:36:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 116 pruned nodes, max_depth=13
# [208]#011train-rmse:0.164664#011validation-rmse:1.10652
# [16:36:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 678 pruned nodes, max_depth=6
# [209]#011train-rmse:0.164604#011validation-rmse:1.10657
# [16:36:45] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 1136 pruned nodes, max_depth=3
# [210]#011train-rmse:0.16456#011validation-rmse:1.10664
# [16:36:45] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 34 extra nodes, 794 pruned nodes, max_depth=15
# [211]#011train-rmse:0.164368#011validation-rmse:1.10666
# [16:36:45] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 720 pruned nodes, max_depth=8
# [212]#011train-rmse:0.16428#011validation-rmse:1.10625
# [16:36:45] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 376 pruned nodes, max_depth=2
# [213]#011train-rmse:0.164259#011validation-rmse:1.10619
# [16:36:45] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 1170 pruned nodes, max_depth=13
# [214]#011train-rmse:0.164093#011validation-rmse:1.1065
# [16:36:46] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 32 extra nodes, 1644 pruned nodes, max_depth=13
# [215]#011train-rmse:0.163878#011validation-rmse:1.10648
# [16:36:46] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 468 pruned nodes, max_depth=0
# [216]#011train-rmse:0.163878#011validation-rmse:1.10648
# [16:36:46] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 36 extra nodes, 1918 pruned nodes, max_depth=13
# [217]#011train-rmse:0.163721#011validation-rmse:1.10663
# [16:36:46] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 570 pruned nodes, max_depth=5
# [218]#011train-rmse:0.163674#011validation-rmse:1.10672
# [16:36:46] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 246 pruned nodes, max_depth=6
# [219]#011train-rmse:0.163597#011validation-rmse:1.10607
# [16:36:47] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 1698 pruned nodes, max_depth=9
# [220]#011train-rmse:0.163475#011validation-rmse:1.10614
# [16:36:47] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 1036 pruned nodes, max_depth=0
# [221]#011train-rmse:0.163475#011validation-rmse:1.10614
# [16:36:47] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 38 extra nodes, 428 pruned nodes, max_depth=16
# [222]#011train-rmse:0.163336#011validation-rmse:1.10627
# [16:36:47] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 954 pruned nodes, max_depth=10
# [223]#011train-rmse:0.163235#011validation-rmse:1.10641
# [16:36:47] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 32 extra nodes, 1150 pruned nodes, max_depth=15
# [224]#011train-rmse:0.163097#011validation-rmse:1.10652
# [16:36:48] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 300 pruned nodes, max_depth=2
# [225]#011train-rmse:0.163086#011validation-rmse:1.10649
# [16:36:48] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 644 pruned nodes, max_depth=0
# [226]#011train-rmse:0.163086#011validation-rmse:1.10649
# [16:36:48] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 1596 pruned nodes, max_depth=6
# [227]#011train-rmse:0.163044#011validation-rmse:1.1065
# [16:36:48] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 56 extra nodes, 534 pruned nodes, max_depth=17
# [228]#011train-rmse:0.162759#011validation-rmse:1.10645
# [16:36:48] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 428 pruned nodes, max_depth=2
# [229]#011train-rmse:0.162753#011validation-rmse:1.10635
# [16:36:49] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 570 pruned nodes, max_depth=0
# [230]#011train-rmse:0.162753#011validation-rmse:1.10635
# [16:36:49] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 1542 pruned nodes, max_depth=15
# [231]#011train-rmse:0.162648#011validation-rmse:1.10644
# [16:36:49] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 686 pruned nodes, max_depth=2
# [232]#011train-rmse:0.162638#011validation-rmse:1.10674
# [16:36:49] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 268 pruned nodes, max_depth=2
# [233]#011train-rmse:0.162615#011validation-rmse:1.10686
# [16:36:49] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 32 extra nodes, 702 pruned nodes, max_depth=16
# [234]#011train-rmse:0.162497#011validation-rmse:1.10683
# [16:36:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 874 pruned nodes, max_depth=4
# [235]#011train-rmse:0.162453#011validation-rmse:1.10683
# [16:36:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 32 extra nodes, 708 pruned nodes, max_depth=16
# [236]#011train-rmse:0.162329#011validation-rmse:1.10672
# [16:36:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 1962 pruned nodes, max_depth=8
# [237]#011train-rmse:0.162252#011validation-rmse:1.1068
# [16:36:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 326 pruned nodes, max_depth=0
# [238]#011train-rmse:0.162252#011validation-rmse:1.1068
# [16:36:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 26 extra nodes, 626 pruned nodes, max_depth=12
# [239]#011train-rmse:0.162131#011validation-rmse:1.10688
# Stopping. Best iteration:
# [219]#011train-rmse:0.163597#011validation-rmse:1.10607
#
# Training seconds: 99
# Billable seconds: 99

# %%
xgb_optim.init_predictor()
# Out:
# Parameter image will be renamed to image_uri in SageMaker Python SDK v2.
# -------------!

# %%
trainval = xgb_optim.sets['trainval']['ori'].copy()
trainval.set_index('time', drop=True, inplace=True)
trainval.to_csv('./results/trainval_{}.csv'.format(name))

test_result = xgb_optim.predict('test', unscaled=False)
test_result.to_csv('./results/test_{}.csv'.format(name))

test_result_unscaled = xgb_optim.predict('test', unscaled=True)
test_result_unscaled.to_csv('./results/testunscaled_{}.csv'.format(name))

trade_result = source.metric.trade(test_result_unscaled, target)
# print('RMSE: ', RMSE(test_result))
# Out:
# Cumulative Returns: 1.83e+06%, Sharpe Ratio : 2.6654e-01

# %%
print('RMSE: ', source.metric.RMSE(test_result, target))
# Out:
# RMSE:  0.5938107615642674

# %%
source.plot.plot_results({"Test": test_result}, 'BTC Price (Scaled) - ' + name, 'BTC')

# %%
source.plot.plot_results({"Train": trainval, 'Test': test_result_unscaled}, 'BTC Price (Unscaled) - ' + name, 'BTC', scale='log')

# %%
source.plot.plot_history({name: trade_result}, 'Trading Result - ' + name)

# %%
collection[name].cleanup()

# %%
tuner.best_training_job()
# Out:
# 'xgboost-210206-1616-020-468ab9d0'

# %%
import boto3
client = boto3.client('sagemaker')

# %%
client.describe_training_job(TrainingJobName=str(tuner.best_training_job()))['HyperParameters']
# Out:
# {'_tuning_objective_metric': 'validation:rmse',
#  'early_stopping_rounds': '20',
#  'eta': '0.05410745565672248',
#  'gamma': '1.9164529523379112',
#  'max_depth': '18',
#  'min_child_weight': '2',
#  'num_round': '300',
#  'objective': 'reg:linear',
#  'seed': '100',
#  'subsample': '0.6339124917100728'}

# %% [markdown]
# {'_tuning_objective_metric': 'validation:rmse',
#  'early_stopping_rounds': '20',
#  'eta': '0.05410745565672248',
#  'gamma': '1.9164529523379112',
#  'max_depth': '18',
#  'min_child_weight': '2',
#  'num_round': '300',
#  'objective': 'reg:linear',
#  'seed': '100',
#  'subsample': '0.6339124917100728'}
